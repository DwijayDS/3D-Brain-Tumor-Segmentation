# %% [markdown]
# """
# COMPLETELY NEW VERSION OF UNET DESIGNED FOR BRAIN TUMOUR SEGMENTATION
#
# SPECS:
#
# 1. Input size  is 240x240x4 for each image
#
# 2. BRATS dataset
#
# 3. DICE LOSS IS TAKEN AS A LOSS FUNCTION
#
# 4. MULTICLASS SEGMENTATION HAS BEEN IMPLEMENTED
#
#
# DESC:
#
# HERE OUR PREDICTION WILL HAVE 4 DIMENSIONS(because we have 4 classes) FOR EACH IMAGE. THESE 4 PREDICTIONS are compared with hot encoded label(Ground truth)
# THIS IN A WAY TRAINS THE SYSTEM TO HOT ENCODE THE PREDICTIONS TOO.
# WE ARE TRYING TO IMPLEMENT THE ABOVE STATED MODEL TO IMPLEMENT MULTICLASS SEGEMENTATION. BUT HAD TO CHANGE SOME THINGS WHICH ARE STATED BELOW
#
# PROBLEMS AND CHANGES:
#
# 1. Faced the problem of class imbalance. So in this version we multiply dice coefficient for each class with certain weight. this weight is reciprocal of the frequency of that class
#
# 2. The problem of class imbalance still persists and dice coeff is more than 1. So i this version we have implemented a new dice coefficient function.
#
#
# FUTURE:
#
# 1. IMPROVING DICE COEFFICIENT
#
# 2. 3D IMPLEMENTATION

# %%
'''Mounting Google Drive on the Colab notebook'''
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#file_image = '/content/gdrive/My Drive/Brain_Tumour_segmentation/Train_image.hdf5'
import h5py
#dataset has data of 484 patients. (155 images of each patient)
#data is extracted using 4 different techniques
#size of data of 1 patient is [240,240,155,4]
#for 2D segmentation we stack in 3rd dimension (axis=2)
#train_image
image_store = h5py.File("/content/gdrive/My Drive/Brain_Tumour_segmentation/Train_image.hdf5", "r")
#train_labels
label_store = h5py.File("/content/gdrive/My Drive/Brain_Tumour_segmentation/Train_label.hdf5", "r")
train_images = image_store["image"]
train_labels = label_store["label"]
#print('hi')

# %%
'''IMPORTING LIBRARIES'''
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import time
import math
import os
'''Clearing tesorflow computation graph'''
tf.reset_default_graph()

# %%
'''DEFINING VARIABLES'''

batch_size=1              #batch size taken at a time
n_class = 4                #number of classes in the label

'''PLACEHOLDER for input and output of UNET'''
'''Here we crop the 155x240x240 image to  160x160x192 by repeating the last layer 5 times to convert 155 to 160'''
X = tf.placeholder(shape=[None,160,160,192,4], dtype=tf.float32, name='input_image')
y = tf.placeholder(shape=[None,160,160,192,1], dtype=tf.int64, name='hot_encode_label')


'''Batch variable exraction from h5py file (used by functions 'rnadom_h5py_batch' and 'test_batch')'''
out_img = np.empty((240,240,batch_size*155,4),dtype=np.float32)
out_label = np.empty((240,240,batch_size*155,1),dtype=np.int64)

# %% [markdown]
# DEFINING ALL THE REQUIRED FUNCTIONS

# %%
'''COMPUTATION GRAPH Function Definitions'''


def left_filter_def(ker_size,in_chan,out_chan,name='left_filter'):
    '''Defining a filter variable to perform convolution'''
    stddev = np.sqrt(4/(ker_size*ker_size*ker_size*ker_size*in_chan*out_chan))           #HE initialization
    if stddev < 0.0008:
        stddev = 0.0008
    return (tf.Variable(tf.truncated_normal([ker_size,ker_size,ker_size,in_chan,out_chan],stddev=stddev),name=name))


def right_filter_def(ker_size,in_chan,out_chan,name='right_filter'):
    '''Defining a filter variable to perform transpose convolution'''
    stddev = np.sqrt(4/(ker_size*ker_size*ker_size*ker_size*in_chan*out_chan))
    if stddev < 0.0008:
        stddev = 0.0008
    return (tf.Variable(tf.truncated_normal([ker_size,ker_size,ker_size,out_chan,in_chan],stddev=stddev),name=name))


def Conv_layer(input_im,filter_mask,stride,activation='None',name='conv'):
    '''Function to perform Convolution and apply activation filter'''
    '''Convolution'''
    conv = tf.nn.conv3d(input_im,filter_mask,strides = [1,stride,stride,stride,1], padding = "SAME",name=name)
    #norm_conv = tf.layers.batch_normalization(conv, training=training, momentum=0.9)
    '''Activation'''
    if activation == 'relu':
        return(tf.nn.relu(conv))
    elif activation == 'softmax':
        return(tf.nn.softmax(conv,axis=-1))
    elif activation == 'elu':
        return(tf.nn.elu(conv))
    else:
        #activation == 'None'
        return(conv)
    

def Deconv_layer(input_im,filter_mask,stride,activation='None',name='De_conv'):
    '''Function to perform Transpose Convolution and apply activation filter'''
    '''Transpose Convolution'''
    inp_shape = np.shape(input_im) #tf.shape()
    out_shape = [batch_size]+[int(inp_shape[1].value*2), int(inp_shape[2].value*2),int(inp_shape[3].value*2), int(inp_shape[4].value/2)]
    
    conv = tf.nn.conv3d_transpose(input_im, filter_mask, out_shape, strides = [1,stride,stride,stride,1], padding = "SAME",name=name)
    #norm_conv = tf.layers.batch_normalization(conv, training=training, momentum=0.9)
    '''Activation'''
    if activation == 'relu':
        return(tf.nn.relu(conv))
    elif activation == 'softmax':
        return(tf.nn.softmax(conv,axis=-1))
    elif activation == 'elu':
        return(tf.nn.elu(conv))
    else:
        #activation == 'None'
        return(conv)

# %%
'''Functions for batch Extraction and pre processing'''

def normalizing_input():
    '''normalization of each input channels'''
    global out_img
    '''CHANNEL INFO'''
    # maximum value found using function called "Finding_maximum_to_normalise "
    #'''max value for dimension 4 is 5337.0'''
    #'''max value for dimension 3 is 11737.0'''
    #'''max value for dimension 2 is 9751.0'''
    #'''max value for dimension 1 is 6476.0'''
    out_img[:,:,:,0] = out_img[:,:,:,0]/6476.0
    out_img[:,:,:,1] = out_img[:,:,:,1]/9751.0
    out_img[:,:,:,2] = out_img[:,:,:,2]/11737.0
    out_img[:,:,:,3] = out_img[:,:,:,3]/5337.0
    
    

def crop_image_fit_brain(in_image):
    '''cropping size was found using the code finding_brain.ipynb'''
    left = 19
    right= 210
    top  = 38
    bot  = 199
    out_image = in_image[top:(bot-1),left:(right+1),:,:]
    return (out_image)


def Pre_processing_3D(a):
    '''Function to roll axis to convert array into[depth,width,height,channels] and the divide it in batches'''
    #print(np.shape(a))
    b = np.rollaxis(a,2, 0)
    #print(np.shape(b))
    #image shape
    out_arr = np.empty(shape=[batch_size,160,np.shape(b)[1],np.shape(b)[2],np.shape(b)[3]])
    for i in range(batch_size):
        start = i*155
        end = start+155
        out_arr[i,0:155,:,:,:] = b[start:end,:,:,:]
    
    a = [out_arr[:,154:155,:,:,:]]*5
    out_arr[:,155:160,:,:,:] = a[0]
    
    '''clippig data from front of each batch'''
    '''to fit the model we remove first 3 slices of each batch'''
    '''shape of a is [batch_size,depth,width,height,channels]'''
    out_send = out_arr[:,:,:,:,:]
    #print("arr",np.shape(out_arr),"send",np.shape(out_send))
    return (out_send)

def random_rotate(in_image,in_label):
    
    check = np.random.random(1)[0]
    if check<0.25:
        out_image = in_image[:,:,::-1,:,:]
        out_lab = in_label[:,:,::-1,:,:]
        
    elif check<0.50:
        
        out_image = in_image[:,:,:,::-1,:]
        out_lab = in_label[:,:,:,::-1,:]
        
    elif check<0.75:
        
        out_image = in_image[:,::-1,:,:,:]
        out_lab = in_label[:,::-1,:,:,:]
        
    else:
        out_image =in_image
        out_lab = in_label
    
    return (out_image,out_lab)



def random_h5py_batch(current_batch_no,permute_mat):
    '''Function to take batches randomly'''
    global out_img
    global out_label
    
    '''training info'''
    train_info = 300  #100 patients with 155 images each

    if current_batch_no == 0:
        no_of_batches = train_info//batch_size  
        permute_mat = np.random.permutation(no_of_batches)
    
    start = permute_mat[current_batch_no]*batch_size*155
    end = start + (batch_size*155)
    train_images.read_direct(out_img,np.s_[:,:,start:end,:])
    train_labels.read_direct(out_label,np.s_[:,:,start:end,:])
    current_batch_no += 1
    #print(len(out_img))
    '''Input normalization'''
    normalizing_input()
    '''normalization oof labels'''
    #out_label = out_label
    #normalizing_label()
    '''converting multi class to dual class'''
    #out_label = convert_dual_class(out_label)
    '''cropping image and labels'''
    crop_out_image = crop_image_fit_brain(out_img)
    crop_out_label = crop_image_fit_brain(out_label)
    '''Rolling axes'''
    #out_img_send = np.rollaxis(crop_out_image,2, 0)
    '''hot encoding'''
    #out_label_send = crop_out_label
    '''3D conversion'''
    out_img_send = Pre_processing_3D(crop_out_image)
    out_label_send = Pre_processing_3D(crop_out_label)
    '''Data augmentation rotation'''
    #out_img_send,out_label_send = random_rotate(out_img_send,out_label_send)
     
    last=0
    if current_batch_no == len(permute_mat):
        last=1
    
    return (out_img_send,out_label_send,current_batch_no,permute_mat,last)

def test_batch():
    '''Function to take next test batch''' 
    global out_img
    global out_label
    
    '''training and testing info'''
    train_info = 380  #100 patients with 155 images each
    test_info = 484-train_info  #100 patients with 155 images each
    
    no_of_batches = test_info//batch_size  
    permute_mat = np.random.permutation(no_of_batches)
    start = (permute_mat[0]*batch_size*155) +(train_info*155)
    end = start + (155*batch_size)
    train_images.read_direct(out_img,np.s_[:,:,start:end,:])
    train_labels.read_direct(out_label,np.s_[:,:,start:end,:])
    
    '''normalization'''
    normalizing_input()
    #normalizing_label()
    '''croping images and labels'''
    crop_out_image = crop_image_fit_brain(out_img)
    crop_out_label = crop_image_fit_brain(out_label) 
    '''3D processing'''
    out_img_send = Pre_processing_3D(crop_out_image)
    out_label_send = Pre_processing_3D(crop_out_label)
    
    return (out_img_send,out_label_send)

# %%
  
def hot_encode(check_image,depth=n_class,name='hot_encode'):
    '''function for hot encoding images'''
    a = tf.one_hot(indices = check_image, depth=depth,name=name)
    b = tf.transpose(a,perm=[0,1,2,3,5,4])
    return b

#############################################################################################################################
#NEW DICE COEFFICIENT
#############################################################################################################################
def new_dice_loss(y_true, y_pred):
    Ncl = y_pred.shape[-1]
    w = np.zeros(shape=(Ncl,))
    w = tf.reduce_sum(y_true, axis=[0,1,2,3]) + 1
    w = 1/((w))
    a = 0
    total_weight = tf.reduce_sum(w)
    numerator = (y_true*y_pred)+0.0000000000001
    denominator = y_true+y_pred+0.0000000000001
    for i in range(np.shape(w)[0]):
        this_class_weight = (w[i]/total_weight)**2
        a += this_class_weight*(tf.reduce_sum(numerator[:,:,:,:,i])/(tf.reduce_sum(denominator[:,:,:,:,i])))
    
    gen_dice_coef = tf.identity(a,name='dice_coefficent')
    
    return (gen_dice_coef)

#############################################################################################################################
#GENERALIZED DICE LOSS FUNCTION
#############################################################################################################################
def generalized_dice_coeff(y_true, y_pred):
    Ncl = y_pred.shape[-1]
    print(Ncl)
    w = np.zeros(shape=(Ncl,))
    w = tf.reduce_sum(y_true, axis=[0,1,2,3]) + 1
    print(np.shape(w))
    w = 1/((w**2))
    print(np.shape(w))
    # Compute gen dice coef:
    numerator = tf.reduce_sum(y_true*y_pred, axis=[0,1,2,3])
    denominator = tf.reduce_sum(y_true+y_pred, axis=[0,1,2,3])
    num=den=0
    for i in range(np.shape(w)[0]):
        num += w[i]*numerator[i]
        den += w[i]*denominator[i]
            
    #num = tf.reduce_sum(a)
    #den = tf.reduce_sum(b)
    num = num + 0.000000001
    den = den + 0.000000001

    gen_dice_coef = tf.divide((2*num),den,name='dice_coeff')

    return (gen_dice_coef)
#############################################################################################################################
#LOSS FUNCTION
#############################################################################################################################
def hybrid_loss(y_true, y_pred):
    dice = generalized_dice_coeff(y_true, y_pred)
    final_loss = tf.subtract(1.0,dice,name='final_loss')
    return final_loss,dice

# %% [markdown]
# INITIALIZING THE MODEL FILTERS

# %% [markdown]
# DEFINING THE MODEL STRUCTURE

# %%
def predict_model1(X):
    '''Function to define the UNET model'''
    '''MODEL1 Filter definition'''
    '''LEFT'''
    
    filter1 = left_filter_def(3,4,8,name='filter1')
    filter2 = left_filter_def(3,8,16,name='filter2')
    pre_resnet_filter1 = left_filter_def(1,16,8,name='pre_resnet_filter1')
    resnet_filter1 = left_filter_def(3,8,8,name='pre_resnet_filter1')
    
    filter3 = left_filter_def(3,8,16,name='filter3')
    filter4 = left_filter_def(3,16,32,name='filter4')
    pre_resnet_filter2 = left_filter_def(1,32,16,name='pre_resnet_filter2')
    resnet_filter2 = left_filter_def(3,16,16,name='pre_resnet_filter2')
    
    
    filter5 = left_filter_def(3,16,32,name='filter5')
    filter6 = left_filter_def(3,32,64,name='filter6')
    pre_resnet_filter3 = left_filter_def(1,64,32,name='pre_resnet_filter3')
    resnet_filter3 = left_filter_def(3,32,32,name='pre_resnet_filter3')
    
    
    filter7 = left_filter_def(3,32,64,name='filter7')
    filter8 = left_filter_def(3,64,128,name='filter8')
    pre_resnet_filter4 = left_filter_def(1,128,64,name='pre_resnet_filter4')
    resnet_filter4 = left_filter_def(3,64,64,name='pre_resnet_filter5')
    
    
    filter9 = left_filter_def(3,64,128,name='filter9')
    pre_resnet_filter5 = left_filter_def(3,128,128,name='pre_resnet_filter5')
    resnet_filter5 = left_filter_def(3,128,128,name='pre_resnet_filter5')
    filter10= left_filter_def(3,128,64,name='filter10')
    
    '''RIGHT'''
    
    filter11 = right_filter_def(3,128,64,name='filter11')
    filter12 = left_filter_def(3,64,64,name='filter12')
    resnet_filter6 = left_filter_def(3,64,64,name='pre_resnet_filter6')
    filter13 = left_filter_def(3,64,32,name='filter13')
    
    filter14 = right_filter_def(3,64,32,name='filter14')
    filter15 = left_filter_def(3,32,32,name='filter15')
    resnet_filter7 = left_filter_def(3,32,32,name='pre_resnet_filter7')
    filter16 = left_filter_def(3,32,16,name='filter16')
    
    filter17 = right_filter_def(3,32,16,name='filter17')
    filter18 = left_filter_def(3,16,16,name='filter18')
    resnet_filter8 = left_filter_def(3,16,16,name='pre_resnet_filter8')
    filter19 = left_filter_def(3,16,8,name='filter19')
    
    filter20 = right_filter_def(3,16,8,name='filter20')
    filter21 = left_filter_def(3,8,8,name='filter21')
    resnet_filter9 = left_filter_def(3,8,8,name='pre_resnet_filter8')
    filter22 = left_filter_def(3,8,n_class,name='filter22')
    
    
    with tf.name_scope("BLOCK1"):
        '''BLOCK1'''
        CNN1 = Conv_layer(X,filter1,stride=1,activation='relu',name='CNN1')
        #print ("CNN1",np.shape(CNN1))
        CNN2 = Conv_layer(CNN1,filter2,stride=1,activation='relu',name='CNN2')
        #print ("CNN2",np.shape(CNN2))
        pre_CNN1 = Conv_layer(CNN2,pre_resnet_filter1,stride=1,activation='relu',name='pre_resnet_filter1CNN2')
        resnet_CNN1 = tf.add(Conv_layer(pre_CNN1,resnet_filter1,stride=1,activation='relu'),CNN1,name='resnet_filter1CNN2') 
        pool1 = tf.nn.max_pool3d(resnet_CNN1,ksize=[1,2,2,2,1],strides=[1,2,2,2,1],padding='VALID',name='POOL1')
    
    with tf.name_scope("BLOCK2"):
        '''BLOCK2'''
        CNN3 = Conv_layer(pool1,filter3,stride=1,activation='relu',name='CNN3')
        #print ("CNN3",np.shape(CNN3))
        CNN4 = Conv_layer(CNN3,filter4,stride=1,activation='relu',name='CNN4')
        #print ("CNN4",np.shape(CNN4))
        pre_CNN2 = Conv_layer(CNN4,pre_resnet_filter2,stride=1,activation='relu',name='pre_resnet_filter2CNN2')
        resnet_CNN2 = tf.add(Conv_layer(pre_CNN2,resnet_filter2,stride=1,activation='relu'),CNN3,name='resnet_filter2CNN2') 

        pool2 = tf.nn.max_pool3d(resnet_CNN2,ksize=[1,2,2,2,1],strides=[1,2,2,2,1],padding='VALID',name='POOL2')
    
    with tf.name_scope("BLOCK3"):
        '''BLOCK3'''
        CNN5 = Conv_layer(pool2,filter5,stride=1,activation='relu',name='CNN5')
        #print ("CNN5",np.shape(CNN5))
        CNN6 = Conv_layer(CNN5,filter6,stride=1,activation='relu',name='CNN6')
        #print ("CNN6",np.shape(CNN6))
        pre_CNN3 = Conv_layer(CNN6,pre_resnet_filter3,stride=1,activation='relu',name='pre_resnet_filter3CNN2')
        resnet_CNN3 = tf.add(Conv_layer(pre_CNN3,resnet_filter3,stride=1,activation='relu'),CNN5,name='resnet_filter3CNN2')
        pool3 = tf.nn.max_pool3d(resnet_CNN3,ksize=[1,2,2,2,1],strides=[1,2,2,2,1],padding='VALID',name='POOL3')
    
    with tf.name_scope("BLOCK4"):
        '''BLOCK4'''
        CNN7 = Conv_layer(pool3,filter7,stride=1,activation='relu',name='CNN7')
        #print ("CNN7",np.shape(CNN7))
        CNN8 = Conv_layer(CNN7,filter8,stride=1,activation='relu',name='CNN8')
        #print ("CNN8",np.shape(CNN8))
        pre_CNN4 = Conv_layer(CNN8,pre_resnet_filter4,stride=1,activation='relu',name='pre_resnet_filter4CNN2')
        resnet_CNN4 = tf.add(Conv_layer(pre_CNN4,resnet_filter4,stride=1,activation='relu'),CNN7,name='resnet_filter4CNN2')

        pool4 = tf.nn.max_pool3d(resnet_CNN4,ksize=[1,2,2,2,1],strides=[1,2,2,2,1],padding='VALID',name='POOL4')
    
    with tf.name_scope("BLOCK5"):
        '''BLOCK5'''
        CNN9 = Conv_layer(pool4,filter9,stride=1,activation='relu',name='CNN9')
        #print ("CNN9",np.shape(CNN9))
        pre_CNN5 = Conv_layer(CNN9,pre_resnet_filter5,stride=1,activation='relu',name='pre_resnet_filter5CNN2')
        resnet_CNN5 = tf.add(Conv_layer(pre_CNN5,resnet_filter5,stride=1,activation='relu'),CNN9,name='resnet_filter5CNN2')
        CNN10 = Conv_layer(resnet_CNN5,filter10,stride=1,activation='relu',name='CNN10')
        #print ("CNN10",np.shape(CNN10))
    
    '''Moving UP'''
    
    with tf.name_scope("BLOCK6"):
        '''BLOCK6'''
        concat1 = tf.concat([CNN10,pool4],axis=4,name='CONCAT1')
        #print ("concat1",np.shape(concat1))
        DCNN1= Deconv_layer(concat1,filter11,stride=2,activation='relu',name='DE_CONV1')
        #print ("DCNN1",np.shape(DCNN1))
        CNN11 = Conv_layer(DCNN1,filter12,stride=1,activation='relu',name='CNN11')
        #print ("CNN11",np.shape(CNN11))
        resnet_CNN6 = tf.add(Conv_layer(CNN11,resnet_filter6,stride=1,activation='relu'),DCNN1,name='resnet_filter6CNN2')
        CNN12 = Conv_layer(resnet_CNN6,filter13,stride=1,activation='relu',name='CNN12')
        #print ("CNN12",np.shape(CNN12))
    
    with tf.name_scope("BLOCK7"):
        '''BLOCK7'''
        concat2 = tf.concat([CNN12,pool3],axis=4,name='CONCAT2')
        #print ("concat2",np.shape(concat2))
        DCNN2= Deconv_layer(concat2,filter14,stride=2,activation='relu',name='DE_CONV2')
        #print ("DCNN2",np.shape(DCNN2))
        CNN13 = Conv_layer(DCNN2,filter15,stride=1,activation='relu',name='CNN13')
        #print ("CNN13",np.shape(CNN13))
        resnet_CNN7 = tf.add(Conv_layer(CNN13,resnet_filter7,stride=1,activation='relu'),DCNN2,name='resnet_filter7CNN2')
        CNN14 = Conv_layer(resnet_CNN7,filter16,stride=1,activation='relu',name='CNN14')
        #print ("CNN14",np.shape(CNN14))
    
    with tf.name_scope("BLOCK8"):
        '''BLOCK8'''
        concat3 = tf.concat([CNN14,pool2],axis=4,name='CONCAT3')
        #print ("concat3",np.shape(concat3))
        DCNN3= Deconv_layer(concat3,filter17,stride=2,activation='relu',name='DE_CONV3')
        #print ("DCNN3",np.shape(DCNN3))
        CNN15 = Conv_layer(DCNN3,filter18,stride=1,activation='relu',name='CNN14')
        #print ("CNN15",np.shape(CNN15))
        resnet_CNN8 = tf.add(Conv_layer(CNN15,resnet_filter8,stride=1,activation='relu'),DCNN3,name='resnet_filter8CNN2')
        CNN16 = Conv_layer(resnet_CNN8,filter19,stride=1,activation='relu',name='CNN15')
        #print ("CNN16",np.shape(CNN16))
        
    with tf.name_scope("BLOCK9"):
        '''BLOCK9'''
        concat4 = tf.concat([CNN16,pool1],axis=4,name='CONCAT4')
        #print ("concat4",np.shape(concat4))
        DCNN4= Deconv_layer(concat4,filter20,stride=2,activation='relu',name='DE_CONV4')
        #print ("DCNN4",np.shape(DCNN4))
        CNN17 = Conv_layer(DCNN4,filter21,stride=1,activation='relu',name='CNN17')
        #print ("CNN17",np.shape(CNN17))
        resnet_CNN9 = tf.add(Conv_layer(CNN17,resnet_filter9,stride=1,activation='relu'),DCNN4,name='resnet_filter9CNN2')
        CNN18 = Conv_layer(resnet_CNN9,filter22,stride=1,activation='softmax',name='CNN18')
        #print ("CNN18",np.shape(CNN18))
    return (CNN18)

# %%
def chose_train_restore(learning_rate =0.0001,n_epochs = 100):
    output_dir = "/content/gdrive/My Drive/Brain_Tumour_segmentation/all_in_one/resnet_dice_loss/saving_model"
    model_checkpoint_file_base = os.path.join(output_dir, "model.ckpt")

    
    if not os.path.exists(model_checkpoint_file_base + ".meta"):
        '''FIRST TIME TRAINING'''
        print("Making new")
        brand_new = True
        
        prediction = predict_model1(X)#logits
        '''----------------------------------------------------------------------------------------------------------------------------------------------------------------'''
        with tf.name_scope("LOSS_FUNCTION"):
            '''using multi dimensional dice'''
            hot_y = hot_encode(y)
            #dice = 1+ dice_coef_multilabel(hot_y,prediction)     #dice loss for verison 1
            dice = generalized_dice_coeff(hot_y[:,:,:,:,:,0], prediction)
            #focal = generalized_focal_loss(hot_y[:,:,:,:,0], prediction)
            #hybrid,dice,focal,sep = find_hybrid_loss(hot_y[:,:,:,:,:,0], prediction, gamma=0.9,alpha=0.8)
            #mean_error = diff_error(hot_y[:,:,:,:,0], prediction)
            #main_loss,dice = hybrid_loss(hot_y[:,:,:,:,0], prediction)
        '''----------------------------------------------------------------------------------------------------------------------------------------------------------------'''
        with tf.name_scope("COST_FUNCTION"):
            '''Cost function''''''Remember to change max to min min to mx depending on loss function'''
            loss = tf.reduce_mean(dice, name="loss")

        saver = tf.train.Saver()
        
    else:
        '''RESTORED MODEL'''
        print("Reloading existing")
        brand_new = False
        saver = tf.train.import_meta_graph(model_checkpoint_file_base + ".meta")
        g = tf.get_default_graph()
        
        #sep = g.get_tensor_by_name("LOSS_FUNCTION/mse_loss:0")
        dice = g.get_tensor_by_name("LOSS_FUNCTION/dice_coeff:0")
        #focal = g.get_tensor_by_name("LOSS_FUNCTION/focal_loss:0")
        #hybrid = g.get_tensor_by_name("LOSS_FUNCTION/hybrid_loss:0")
        #main_loss = g.get_tensor_by_name("LOSS_FUNCTION/final_loss:0")
        prediction = g.get_tensor_by_name("BLOCK9/Softmax:0") 
        loss = g.get_tensor_by_name("COST_FUNCTION/loss:0")
        
        #X = g.get_tensor_by_name("input_image:0")
        #y = g.get_tensor_by_name("hot_encode_label:0")


    
    
    
    '''TRAINING'''
    '''starting session'''
    gpu_option = tf.GPUOptions(per_process_gpu_memory_fraction=0.5)
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_option)) as sess:
        '''Initializing optimizer'''
        if brand_new:
            optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)
            init = tf.global_variables_initializer()
            sess.run(init)
            tf.add_to_collection("optimizer", optimizer)
        else:
            saver = tf.train.Saver()
            saver.restore(sess, model_checkpoint_file_base)
            optimizer = tf.get_collection("optimizer")[0]

        for epoch in range(n_epochs):
            current_batch_no = 0
            permute_mat = 0
            iteration = 0
            while(1):
                #with tf.device('/cpu:0'):
                epoch_x,epoch_y,current_batch_no,permute_mat,last = random_h5py_batch(current_batch_no,permute_mat)
                sess_results = sess.run(optimizer, feed_dict={X: epoch_x, y: epoch_y})
                #print ("epoch",epoch+1,"batch",iteration+1)#,"Cost",sess_results[0])
                
                '''DICE Coefficient for iteration'''
                #with tf.device('/cpu:0'):
                if iteration%10==0:
                    acc_train = (dice.eval(feed_dict={X: epoch_x, y: epoch_y}))
                    #train_loss,train_dice = sess.run([main_loss,dice], feed_dict={X: epoch_x, y: epoch_y})
                    test_images, test_labels = test_batch()
                    acc_test = (dice.eval(feed_dict={X: test_images, y: test_labels}))
                    #test_loss,test_dice = sess.run([main_loss,dice], feed_dict={X: test_images, y: test_labels})
                    print("Minibatch at","Epoch", epoch+1,"batch",iteration+1, "Train Dice Coefficient", acc_train, "Test Dice Coefficient", acc_test)
                    #print("Minibatch at","Epoch", epoch+1,"batch",iteration+1, "Train Loss:", train_loss, "Train Dice Coeff",train_dice/4,"Test Loss:", test_loss, "Test Dice Coeff",test_dice/4)
                    #print("After Epoch", epoch+1, "Hybrid Train accuracy:", 1-hybrid_train, "Dice Train accuracy:", 1-dice_train, "Focal Train accuracy:", 1-focal_train, "MSE Train accuracy:", 1-diff_train)
                if last ==1:
                    break
                iteration +=1
            test_images, test_labels = test_batch()
            #hybrid_test,dice_test,focal_test,diff_test = sess.run([hybrid,dice,focal,sep], feed_dict={X: test_images, y: test_labels})
            diff_test = sess.run(dice, feed_dict={X: test_images, y: test_labels})
            #test_loss,test_dice = sess.run([main_loss,dice], feed_dict={X: test_images, y: test_labels})
            print("-------------------------------------------------------------------------------------------------------")
            #print("After Epoch", epoch+1, "Hybrid Test accuracy:", 1-hybrid_test, "Dice Test accuracy:", 1-dice_test, "Focal Test accuracy:", 1-focal_test, "MSE Test accuracy:", 1-diff_test)
            #print("After Epoch", epoch+1,"Test Loss:", test_loss, "Test Dice Coeff",test_dice/4)
            print("After Epoch", epoch+1,"Test Dice Coeff",diff_test)
            print("-------------------------------------------------------------------------------------------------------")
            '''saving model after each epoch'''
            save_path = tf.train.Saver(max_to_keep=1).save(sess, model_checkpoint_file_base)
            
            if epoch % 1 == 0:
                test_example =   test_images
                test_example_gt = test_labels#np.rollaxis(test_labels,2,0)
                sess_results = sess.run(prediction,feed_dict={X:test_example})

                sess_results = sess_results[0,100,:,:,1] + (2*sess_results[0,100,:,:,2]) + (3*sess_results[0,100,:,:,3])
                test_example = test_example[0,100,:,:,3]
                test_example_gt = test_example_gt[0,100,:,:,:]
                
                plt.figure()
                plt.imshow(np.squeeze(test_example),cmap='gray')
                plt.axis('off')
                plt.title('Original Image')
                plt.savefig('/content/gdrive/My Drive/Brain_Tumour_segmentation/all_in_one/resnet_dice_loss/result/'+str(epoch)+"a_Original_Image.png")
                 
                plt.figure()
                plt.imshow(np.squeeze(test_example_gt),cmap='gray')
                plt.axis('off')
                plt.title('Ground Truth Mask')
                plt.savefig('/content/gdrive/My Drive/Brain_Tumour_segmentation/all_in_one/resnet_dice_loss/result/'+str(epoch)+"b_Original_Mask.png")

                plt.figure()
                plt.imshow(np.squeeze(sess_results),cmap='gray')
                plt.axis('off')
                plt.title('Generated Mask')
                plt.savefig('/content/gdrive/My Drive/Brain_Tumour_segmentation/all_in_one/resnet_dice_loss/result/'+str(epoch)+"c_Generated_Mask.png")

                plt.close('all')

# %% [markdown]
# COMMENTS ON DICE LOSS AND ACCURACY
#
# 1. Under the name_scope "LOSS FUNCTION", the variable named dice corresponds to dice loss and since the function dice_multipleclass() returns a value between -1 and 0(both included) , we add 1. Also another reason for this is there is no maximize function in adam optimizer(or any other optimizing function).
#
# 2. While printing  the accuracy (everywhere)  we have to print dice coefficient and not dice loss therefore we add 1 to the dice_loss calculation

# %%
chose_train_restore()
# Out:
# Making new
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 4
# (4,)
# (4,)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Minibatch at Epoch 1 batch 1 Train Dice Coefficient 0.01036411 Test Dice Coefficient 0.0015869191
# Minibatch at Epoch 1 batch 11 Train Dice Coefficient 0.016014487 Test Dice Coefficient 0.0008400524
# Minibatch at Epoch 1 batch 21 Train Dice Coefficient 0.00052013213 Test Dice Coefficient 9.709561e-05
# Minibatch at Epoch 1 batch 31 Train Dice Coefficient 0.005894134 Test Dice Coefficient 0.0017809693
# Minibatch at Epoch 1 batch 41 Train Dice Coefficient 0.011014125 Test Dice Coefficient 0.00013961135
# Minibatch at Epoch 1 batch 51 Train Dice Coefficient 9.344829e-06 Test Dice Coefficient 0.004390028
# Minibatch at Epoch 1 batch 61 Train Dice Coefficient 0.010522991 Test Dice Coefficient 5.2354375e-05
# Minibatch at Epoch 1 batch 71 Train Dice Coefficient 0.001956118 Test Dice Coefficient 0.0016782797
# Minibatch at Epoch 1 batch 81 Train Dice Coefficient 0.0034168155 Test Dice Coefficient 0.005751637
# Minibatch at Epoch 1 batch 91 Train Dice Coefficient 0.003614161 Test Dice Coefficient 0.0029165626
# Minibatch at Epoch 1 batch 101 Train Dice Coefficient 0.0025552844 Test Dice Coefficient 0.0015281681
# Minibatch at Epoch 1 batch 111 Train Dice Coefficient 0.009265392 Test Dice Coefficient 0.00015340064
# Minibatch at Epoch 1 batch 121 Train Dice Coefficient 0.0017163033 Test Dice Coefficient 0.0036001187
# Minibatch at Epoch 1 batch 131 Train Dice Coefficient 6.6874534e-05 Test Dice Coefficient 0.0010964187
# Minibatch at Epoch 1 batch 141 Train Dice Coefficient 0.00027878935 Test Dice Coefficient 4.0155087e-06
# Minibatch at Epoch 1 batch 151 Train Dice Coefficient 8.506764e-05 Test Dice Coefficient 1.2069706e-05
# Minibatch at Epoch 1 batch 161 Train Dice Coefficient 7.3347366e-08 Test Dice Coefficient 5.4973054e-08
# Minibatch at Epoch 1 batch 171 Train Dice Coefficient 5.7456236e-07 Test Dice Coefficient 4.107763e-06
# Minibatch at Epoch 1 batch 181 Train Dice Coefficient 2.0619047e-05 Test Dice Coefficient 4.560572e-05
# Minibatch at Epoch 1 batch 191 Train Dice Coefficient 1.629723e-05 Test Dice Coefficient 6.0932405e-05
# Minibatch at Epoch 1 batch 201 Train Dice Coefficient 8.6420194e-05 Test Dice Coefficient 0.0002223837
# Minibatch at Epoch 1 batch 211 Train Dice Coefficient 5.882697e-08 Test Dice Coefficient 0.0002663103
# Minibatch at Epoch 1 batch 221 Train Dice Coefficient 2.1060034e-05 Test Dice Coefficient 1.044691e-06
# Minibatch at Epoch 1 batch 231 Train Dice Coefficient 2.468448e-05 Test Dice Coefficient 0.00031027693
# Minibatch at Epoch 1 batch 241 Train Dice Coefficient 1.0383415e-06 Test Dice Coefficient 1.3670879e-07
# Minibatch at Epoch 1 batch 251 Train Dice Coefficient 2.5735279e-05 Test Dice Coefficient 0.00017109791
# Minibatch at Epoch 1 batch 261 Train Dice Coefficient 3.921616e-06 Test Dice Coefficient 4.805757e-05
# Minibatch at Epoch 1 batch 271 Train Dice Coefficient 5.4359673e-05 Test Dice Coefficient 1.2581251e-05
# Minibatch at Epoch 1 batch 281 Train Dice Coefficient 2.0367735e-05 Test Dice Coefficient 0.0001342004
# Minibatch at Epoch 1 batch 291 Train Dice Coefficient 5.4287843e-06 Test Dice Coefficient 5.4966284e-05
# -------------------------------------------------------------------------------------------------------
# After Epoch 1 Test Dice Coeff 1.0062794e-05
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 2 batch 1 Train Dice Coefficient 2.2016584e-05 Test Dice Coefficient 3.5642304e-07
# Minibatch at Epoch 2 batch 11 Train Dice Coefficient 5.212208e-05 Test Dice Coefficient 1.7666742e-05
# Minibatch at Epoch 2 batch 21 Train Dice Coefficient 7.4468144e-06 Test Dice Coefficient 6.16096e-05
# Minibatch at Epoch 2 batch 31 Train Dice Coefficient 0.0003841204 Test Dice Coefficient 6.748912e-05
# Minibatch at Epoch 2 batch 41 Train Dice Coefficient 0.00010537198 Test Dice Coefficient 3.2888896e-05
# Minibatch at Epoch 2 batch 51 Train Dice Coefficient 7.496679e-06 Test Dice Coefficient 1.4380272e-05
# Minibatch at Epoch 2 batch 61 Train Dice Coefficient 3.392009e-09 Test Dice Coefficient 5.1328332e-08
# Minibatch at Epoch 2 batch 71 Train Dice Coefficient 1.2686478e-06 Test Dice Coefficient 7.377936e-07
# Minibatch at Epoch 2 batch 81 Train Dice Coefficient 6.7491046e-06 Test Dice Coefficient 1.3198759e-05
# Minibatch at Epoch 2 batch 91 Train Dice Coefficient 7.571594e-08 Test Dice Coefficient 3.837329e-06
# Minibatch at Epoch 2 batch 101 Train Dice Coefficient 2.1771726e-05 Test Dice Coefficient 2.399182e-05
# Minibatch at Epoch 2 batch 111 Train Dice Coefficient 2.3951607e-05 Test Dice Coefficient 1.4053727e-07
# Minibatch at Epoch 2 batch 121 Train Dice Coefficient 1.7937751e-05 Test Dice Coefficient 3.8751846e-06
# Minibatch at Epoch 2 batch 131 Train Dice Coefficient 5.9456244e-05 Test Dice Coefficient 0.00015000884
# Minibatch at Epoch 2 batch 141 Train Dice Coefficient 1.5618895e-11 Test Dice Coefficient 5.858051e-06
# Minibatch at Epoch 2 batch 151 Train Dice Coefficient 7.9832735e-06 Test Dice Coefficient 0.00014954913
# Minibatch at Epoch 2 batch 161 Train Dice Coefficient 4.1563834e-07 Test Dice Coefficient 6.64756e-05
# Minibatch at Epoch 2 batch 171 Train Dice Coefficient 4.0873124e-06 Test Dice Coefficient 2.4629304e-05
# Minibatch at Epoch 2 batch 181 Train Dice Coefficient 6.8244076e-06 Test Dice Coefficient 0.0005003568
# Minibatch at Epoch 2 batch 191 Train Dice Coefficient 0.00020899567 Test Dice Coefficient 0.0005239368
# Minibatch at Epoch 2 batch 201 Train Dice Coefficient 7.3554864e-09 Test Dice Coefficient 9.74502e-06
# Minibatch at Epoch 2 batch 211 Train Dice Coefficient 1.8584831e-07 Test Dice Coefficient 4.466449e-05
# Minibatch at Epoch 2 batch 221 Train Dice Coefficient 2.9064944e-05 Test Dice Coefficient 1.8906846e-06
# Minibatch at Epoch 2 batch 231 Train Dice Coefficient 2.55353e-05 Test Dice Coefficient 2.5303465e-05
# Minibatch at Epoch 2 batch 241 Train Dice Coefficient 1.4321299e-05 Test Dice Coefficient 2.5132176e-05
# Minibatch at Epoch 2 batch 251 Train Dice Coefficient 5.60024e-08 Test Dice Coefficient 4.6744386e-08
# Minibatch at Epoch 2 batch 261 Train Dice Coefficient 1.2260328e-07 Test Dice Coefficient 4.2405394e-05
# Minibatch at Epoch 2 batch 271 Train Dice Coefficient 5.6535578e-06 Test Dice Coefficient 4.40812e-05
# Minibatch at Epoch 2 batch 281 Train Dice Coefficient 6.941609e-05 Test Dice Coefficient 7.76832e-07
# Minibatch at Epoch 2 batch 291 Train Dice Coefficient 8.50826e-06 Test Dice Coefficient 0.00011364639
# -------------------------------------------------------------------------------------------------------
# After Epoch 2 Test Dice Coeff 5.280324e-06
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 3 batch 1 Train Dice Coefficient 2.9526875e-08 Test Dice Coefficient 7.114609e-10
# Minibatch at Epoch 3 batch 11 Train Dice Coefficient 3.266465e-13 Test Dice Coefficient 0.00014903507
# Minibatch at Epoch 3 batch 21 Train Dice Coefficient 0.00016856242 Test Dice Coefficient 6.3006355e-06
# Minibatch at Epoch 3 batch 31 Train Dice Coefficient 3.0867104e-06 Test Dice Coefficient 9.8168175e-06
# Minibatch at Epoch 3 batch 41 Train Dice Coefficient 2.1451595e-07 Test Dice Coefficient 6.995464e-10
# Minibatch at Epoch 3 batch 51 Train Dice Coefficient 2.3725011e-05 Test Dice Coefficient 3.0998093e-05
# Minibatch at Epoch 3 batch 61 Train Dice Coefficient 2.6294415e-13 Test Dice Coefficient 3.8324022e-05
# Minibatch at Epoch 3 batch 71 Train Dice Coefficient 3.0732746e-08 Test Dice Coefficient 4.961626e-05
# Minibatch at Epoch 3 batch 81 Train Dice Coefficient 3.2915118e-06 Test Dice Coefficient 4.287688e-06
# Minibatch at Epoch 3 batch 91 Train Dice Coefficient 6.342963e-05 Test Dice Coefficient 0.00014481926
# Minibatch at Epoch 3 batch 101 Train Dice Coefficient 1.1671077e-05 Test Dice Coefficient 9.45899e-07
# Minibatch at Epoch 3 batch 111 Train Dice Coefficient 3.682044e-05 Test Dice Coefficient 7.2976276e-05
# Minibatch at Epoch 3 batch 121 Train Dice Coefficient 2.886528e-07 Test Dice Coefficient 0.00035198248
# Minibatch at Epoch 3 batch 131 Train Dice Coefficient 7.5414314e-06 Test Dice Coefficient 9.951804e-06
# Minibatch at Epoch 3 batch 141 Train Dice Coefficient 1.0683386e-05 Test Dice Coefficient 0.00014291047
# Minibatch at Epoch 3 batch 151 Train Dice Coefficient 4.84015e-05 Test Dice Coefficient 9.852312e-06
# Minibatch at Epoch 3 batch 161 Train Dice Coefficient 4.0444706e-06 Test Dice Coefficient 7.036707e-05
# Minibatch at Epoch 3 batch 171 Train Dice Coefficient 3.224259e-08 Test Dice Coefficient 6.799155e-10
# Minibatch at Epoch 3 batch 181 Train Dice Coefficient 0.000123685 Test Dice Coefficient 0.000117661664
# Minibatch at Epoch 3 batch 191 Train Dice Coefficient 9.887222e-06 Test Dice Coefficient 0.0001685424
# Minibatch at Epoch 3 batch 201 Train Dice Coefficient 1.6659045e-05 Test Dice Coefficient 0.00010202837
# Minibatch at Epoch 3 batch 211 Train Dice Coefficient 6.6499247e-06 Test Dice Coefficient 1.2114592e-05
# Minibatch at Epoch 3 batch 221 Train Dice Coefficient 3.6840684e-05 Test Dice Coefficient 1.16059276e-07
# Minibatch at Epoch 3 batch 231 Train Dice Coefficient 0.0001351988 Test Dice Coefficient 2.36538e-05
# Minibatch at Epoch 3 batch 241 Train Dice Coefficient 2.5245821e-08 Test Dice Coefficient 3.6394722e-05
# Minibatch at Epoch 3 batch 251 Train Dice Coefficient 5.286231e-05 Test Dice Coefficient 0.00018252178
# Minibatch at Epoch 3 batch 261 Train Dice Coefficient 1.9946197e-05 Test Dice Coefficient 5.7271187e-05
# Minibatch at Epoch 3 batch 271 Train Dice Coefficient 4.422683e-05 Test Dice Coefficient 0.00039649528
# Minibatch at Epoch 3 batch 281 Train Dice Coefficient 2.9662464e-05 Test Dice Coefficient 5.598375e-05
# Minibatch at Epoch 3 batch 291 Train Dice Coefficient 0.000102483085 Test Dice Coefficient 9.624846e-06
# -------------------------------------------------------------------------------------------------------
# After Epoch 3 Test Dice Coeff 3.7797688e-06
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 4 batch 1 Train Dice Coefficient 8.418702e-05 Test Dice Coefficient 7.323765e-07
# Minibatch at Epoch 4 batch 11 Train Dice Coefficient 2.6907654e-13 Test Dice Coefficient 1.642832e-05
# Minibatch at Epoch 4 batch 21 Train Dice Coefficient 4.224181e-06 Test Dice Coefficient 1.452754e-05
# Minibatch at Epoch 4 batch 31 Train Dice Coefficient 2.5713261e-05 Test Dice Coefficient 0.000115545874
# Minibatch at Epoch 4 batch 41 Train Dice Coefficient 8.019635e-06 Test Dice Coefficient 2.1886968e-05
# Minibatch at Epoch 4 batch 51 Train Dice Coefficient 5.084427e-06 Test Dice Coefficient 1.8789195e-05
# Minibatch at Epoch 4 batch 61 Train Dice Coefficient 9.047497e-06 Test Dice Coefficient 4.6206005e-05
# Minibatch at Epoch 4 batch 71 Train Dice Coefficient 0.000113866015 Test Dice Coefficient 6.583528e-05
# Minibatch at Epoch 4 batch 81 Train Dice Coefficient 9.2827594e-07 Test Dice Coefficient 8.690515e-06
# Minibatch at Epoch 4 batch 91 Train Dice Coefficient 7.2938524e-06 Test Dice Coefficient 0.0002481938
# Minibatch at Epoch 4 batch 101 Train Dice Coefficient 7.907351e-08 Test Dice Coefficient 3.7301659e-06
# Minibatch at Epoch 4 batch 111 Train Dice Coefficient 3.7150394e-07 Test Dice Coefficient 3.1894226e-05
# Minibatch at Epoch 4 batch 121 Train Dice Coefficient 2.7217802e-06 Test Dice Coefficient 9.338558e-06
# Minibatch at Epoch 4 batch 131 Train Dice Coefficient 2.852329e-06 Test Dice Coefficient 0.0015776807
# Minibatch at Epoch 4 batch 141 Train Dice Coefficient 1.2364827e-06 Test Dice Coefficient 3.1312837e-05
# Minibatch at Epoch 4 batch 151 Train Dice Coefficient 9.208938e-06 Test Dice Coefficient 8.868379e-06
# Minibatch at Epoch 4 batch 161 Train Dice Coefficient 2.1496705e-06 Test Dice Coefficient 6.142526e-05
# Minibatch at Epoch 4 batch 171 Train Dice Coefficient 2.1278072e-06 Test Dice Coefficient 5.100745e-09
# Minibatch at Epoch 4 batch 181 Train Dice Coefficient 1.726576e-05 Test Dice Coefficient 6.934068e-05
# Minibatch at Epoch 4 batch 191 Train Dice Coefficient 3.6344268e-06 Test Dice Coefficient 9.728365e-06
# Minibatch at Epoch 4 batch 201 Train Dice Coefficient 1.3477519e-05 Test Dice Coefficient 6.985326e-06
# Minibatch at Epoch 4 batch 211 Train Dice Coefficient 2.46351e-05 Test Dice Coefficient 9.611183e-06
# Minibatch at Epoch 4 batch 221 Train Dice Coefficient 3.3842963e-07 Test Dice Coefficient 4.0832433e-06
# Minibatch at Epoch 4 batch 231 Train Dice Coefficient 1.697284e-05 Test Dice Coefficient 0.00011502344
# Minibatch at Epoch 4 batch 241 Train Dice Coefficient 7.017835e-05 Test Dice Coefficient 2.2922346e-05
# Minibatch at Epoch 4 batch 251 Train Dice Coefficient 8.0258105e-05 Test Dice Coefficient 2.293616e-06
# Minibatch at Epoch 4 batch 261 Train Dice Coefficient 9.73735e-06 Test Dice Coefficient 0.00013936847
# Minibatch at Epoch 4 batch 271 Train Dice Coefficient 2.581161e-13 Test Dice Coefficient 2.448307e-05
# Minibatch at Epoch 4 batch 281 Train Dice Coefficient 1.0905717e-05 Test Dice Coefficient 6.4281744e-07
# Minibatch at Epoch 4 batch 291 Train Dice Coefficient 3.8797592e-05 Test Dice Coefficient 9.177744e-06
# -------------------------------------------------------------------------------------------------------
# After Epoch 4 Test Dice Coeff 0.00013527338
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 5 batch 1 Train Dice Coefficient 2.7517122e-13 Test Dice Coefficient 3.821889e-05
# Minibatch at Epoch 5 batch 11 Train Dice Coefficient 4.881563e-08 Test Dice Coefficient 2.1036405e-05
# Minibatch at Epoch 5 batch 21 Train Dice Coefficient 3.297356e-05 Test Dice Coefficient 0.0003545057
# Minibatch at Epoch 5 batch 31 Train Dice Coefficient 1.5149846e-08 Test Dice Coefficient 1.0472759e-05
# Minibatch at Epoch 5 batch 41 Train Dice Coefficient 6.1449543e-09 Test Dice Coefficient 2.50448e-05
# Minibatch at Epoch 5 batch 51 Train Dice Coefficient 4.3775603e-05 Test Dice Coefficient 5.6786146e-05
# Minibatch at Epoch 5 batch 61 Train Dice Coefficient 2.8416565e-05 Test Dice Coefficient 0.000104824714
# Minibatch at Epoch 5 batch 71 Train Dice Coefficient 3.4107368e-06 Test Dice Coefficient 4.4475266e-05
# Minibatch at Epoch 5 batch 81 Train Dice Coefficient 6.908227e-05 Test Dice Coefficient 0.00024796123
# Minibatch at Epoch 5 batch 91 Train Dice Coefficient 4.1235103e-06 Test Dice Coefficient 6.81563e-09
# Minibatch at Epoch 5 batch 101 Train Dice Coefficient 5.7126604e-06 Test Dice Coefficient 3.488191e-05
# Minibatch at Epoch 5 batch 111 Train Dice Coefficient 0.00043099764 Test Dice Coefficient 1.0772866e-06
# Minibatch at Epoch 5 batch 121 Train Dice Coefficient 1.5028171e-11 Test Dice Coefficient 2.0512956e-05
# Minibatch at Epoch 5 batch 131 Train Dice Coefficient 1.617292e-07 Test Dice Coefficient 3.0698445e-06
# Minibatch at Epoch 5 batch 141 Train Dice Coefficient 2.6432136e-13 Test Dice Coefficient 4.7386295e-09
# Minibatch at Epoch 5 batch 151 Train Dice Coefficient 4.7911758e-08 Test Dice Coefficient 4.032125e-05
# Minibatch at Epoch 5 batch 161 Train Dice Coefficient 9.483528e-05 Test Dice Coefficient 4.1400635e-05
# Minibatch at Epoch 5 batch 171 Train Dice Coefficient 2.7541844e-05 Test Dice Coefficient 0.00023591315
# Minibatch at Epoch 5 batch 181 Train Dice Coefficient 0.00016488413 Test Dice Coefficient 0.0001081145
# Minibatch at Epoch 5 batch 191 Train Dice Coefficient 3.7728485e-05 Test Dice Coefficient 1.5564832e-05
# Minibatch at Epoch 5 batch 201 Train Dice Coefficient 3.6408647e-09 Test Dice Coefficient 1.2189936e-07
# Minibatch at Epoch 5 batch 211 Train Dice Coefficient 5.05299e-08 Test Dice Coefficient 1.8182025e-05
# Minibatch at Epoch 5 batch 221 Train Dice Coefficient 1.4605249e-05 Test Dice Coefficient 1.5880398e-05
# Minibatch at Epoch 5 batch 231 Train Dice Coefficient 2.031581e-05 Test Dice Coefficient 0.00015944902
# Minibatch at Epoch 5 batch 241 Train Dice Coefficient 2.6206146e-05 Test Dice Coefficient 3.8377788e-05
# Minibatch at Epoch 5 batch 251 Train Dice Coefficient 9.986289e-06 Test Dice Coefficient 0.00010801636
# Minibatch at Epoch 5 batch 261 Train Dice Coefficient 0.00015743625 Test Dice Coefficient 0.00034636297
# Minibatch at Epoch 5 batch 271 Train Dice Coefficient 6.618612e-05 Test Dice Coefficient 5.200778e-05
# Minibatch at Epoch 5 batch 281 Train Dice Coefficient 1.7243214e-05 Test Dice Coefficient 6.4209205e-05
# Minibatch at Epoch 5 batch 291 Train Dice Coefficient 6.4054784e-06 Test Dice Coefficient 3.8736772e-08
# -------------------------------------------------------------------------------------------------------
# After Epoch 5 Test Dice Coeff 1.0537212e-05
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 6 batch 1 Train Dice Coefficient 1.490276e-05 Test Dice Coefficient 0.00012551965
# Minibatch at Epoch 6 batch 11 Train Dice Coefficient 2.8104475e-13 Test Dice Coefficient 5.5846842e-05
# Minibatch at Epoch 6 batch 21 Train Dice Coefficient 0.00036928203 Test Dice Coefficient 1.4185165e-05
# Minibatch at Epoch 6 batch 31 Train Dice Coefficient 1.0541263e-06 Test Dice Coefficient 0.00024981736
# Minibatch at Epoch 6 batch 41 Train Dice Coefficient 8.5790445e-05 Test Dice Coefficient 0.00011433366
# Minibatch at Epoch 6 batch 51 Train Dice Coefficient 2.7288784e-06 Test Dice Coefficient 2.0103558e-05
# Minibatch at Epoch 6 batch 61 Train Dice Coefficient 2.603035e-08 Test Dice Coefficient 1.1255551e-06
# Minibatch at Epoch 6 batch 71 Train Dice Coefficient 1.2796546e-07 Test Dice Coefficient 3.6864258e-05
# Minibatch at Epoch 6 batch 81 Train Dice Coefficient 6.784909e-05 Test Dice Coefficient 8.920607e-06
# Minibatch at Epoch 6 batch 91 Train Dice Coefficient 0.00041664828 Test Dice Coefficient 6.5636516e-05
# Minibatch at Epoch 6 batch 101 Train Dice Coefficient 1.706927e-06 Test Dice Coefficient 0.00011068361
# Minibatch at Epoch 6 batch 111 Train Dice Coefficient 2.570698e-05 Test Dice Coefficient 9.929672e-05
# Minibatch at Epoch 6 batch 121 Train Dice Coefficient 3.2312066e-08 Test Dice Coefficient 5.7576577e-05
# Minibatch at Epoch 6 batch 131 Train Dice Coefficient 3.3389748e-05 Test Dice Coefficient 3.8108644e-06
# Minibatch at Epoch 6 batch 141 Train Dice Coefficient 7.7284376e-08 Test Dice Coefficient 1.2798161e-07
# Minibatch at Epoch 6 batch 151 Train Dice Coefficient 1.9944448e-05 Test Dice Coefficient 2.1927724e-08
# Minibatch at Epoch 6 batch 161 Train Dice Coefficient 6.9194753e-06 Test Dice Coefficient 3.916035e-05
# Minibatch at Epoch 6 batch 171 Train Dice Coefficient 4.825838e-06 Test Dice Coefficient 5.5676774e-05
# Minibatch at Epoch 6 batch 181 Train Dice Coefficient 0.0001335692 Test Dice Coefficient 0.00011626392
# Minibatch at Epoch 6 batch 191 Train Dice Coefficient 2.3794324e-09 Test Dice Coefficient 1.3680634e-06
# Minibatch at Epoch 6 batch 201 Train Dice Coefficient 1.4523347e-07 Test Dice Coefficient 5.3258386e-06
# Minibatch at Epoch 6 batch 211 Train Dice Coefficient 2.6417182e-13 Test Dice Coefficient 1.1517478e-06
# Minibatch at Epoch 6 batch 221 Train Dice Coefficient 6.6338854e-09 Test Dice Coefficient 2.6814785e-08
# Minibatch at Epoch 6 batch 231 Train Dice Coefficient 2.6135322e-05 Test Dice Coefficient 1.0037751e-05
# Minibatch at Epoch 6 batch 241 Train Dice Coefficient 1.8365166e-05 Test Dice Coefficient 0.00014615979
# Minibatch at Epoch 6 batch 251 Train Dice Coefficient 4.0858567e-06 Test Dice Coefficient 4.5454335e-06
# Minibatch at Epoch 6 batch 261 Train Dice Coefficient 5.760363e-09 Test Dice Coefficient 0.00014043527
# Minibatch at Epoch 6 batch 271 Train Dice Coefficient 1.8243662e-06 Test Dice Coefficient 7.1707683e-07
# Minibatch at Epoch 6 batch 281 Train Dice Coefficient 2.2133583e-05 Test Dice Coefficient 4.6261863e-05
# Minibatch at Epoch 6 batch 291 Train Dice Coefficient 5.9946346e-06 Test Dice Coefficient 0.0001621889
# -------------------------------------------------------------------------------------------------------
# After Epoch 6 Test Dice Coeff 0.00013797545
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 7 batch 1 Train Dice Coefficient 7.4076224e-06 Test Dice Coefficient 0.0001302494
# Minibatch at Epoch 7 batch 11 Train Dice Coefficient 1.31031165e-05 Test Dice Coefficient 7.932108e-07
# Minibatch at Epoch 7 batch 21 Train Dice Coefficient 8.1009115e-05 Test Dice Coefficient 0.00019423311
# Minibatch at Epoch 7 batch 31 Train Dice Coefficient 8.950966e-05 Test Dice Coefficient 0.00015632475
# Minibatch at Epoch 7 batch 41 Train Dice Coefficient 0.0004004968 Test Dice Coefficient 9.65245e-07
# Minibatch at Epoch 7 batch 51 Train Dice Coefficient 8.542628e-06 Test Dice Coefficient 5.409226e-05
# Minibatch at Epoch 7 batch 61 Train Dice Coefficient 2.9950888e-05 Test Dice Coefficient 8.423281e-08
# Minibatch at Epoch 7 batch 71 Train Dice Coefficient 9.5826545e-05 Test Dice Coefficient 6.163304e-05
# Minibatch at Epoch 7 batch 81 Train Dice Coefficient 0.0001980551 Test Dice Coefficient 0.00013590323
# Minibatch at Epoch 7 batch 91 Train Dice Coefficient 1.9483288e-05 Test Dice Coefficient 3.1670484e-06
# Minibatch at Epoch 7 batch 101 Train Dice Coefficient 1.7059136e-06 Test Dice Coefficient 5.6863966e-05
# Minibatch at Epoch 7 batch 111 Train Dice Coefficient 2.7172794e-06 Test Dice Coefficient 1.5789643e-05
# Minibatch at Epoch 7 batch 121 Train Dice Coefficient 1.9035244e-05 Test Dice Coefficient 1.1171111e-06
# Minibatch at Epoch 7 batch 131 Train Dice Coefficient 1.8732634e-07 Test Dice Coefficient 9.502219e-05
# Minibatch at Epoch 7 batch 141 Train Dice Coefficient 3.325774e-06 Test Dice Coefficient 1.976052e-05
# Minibatch at Epoch 7 batch 151 Train Dice Coefficient 1.06511525e-05 Test Dice Coefficient 1.2182409e-05
# Minibatch at Epoch 7 batch 161 Train Dice Coefficient 3.692575e-05 Test Dice Coefficient 8.582647e-06
# Minibatch at Epoch 7 batch 171 Train Dice Coefficient 3.546214e-07 Test Dice Coefficient 4.549926e-06
# Minibatch at Epoch 7 batch 181 Train Dice Coefficient 9.754324e-06 Test Dice Coefficient 0.0001288373
# Minibatch at Epoch 7 batch 191 Train Dice Coefficient 8.1547376e-05 Test Dice Coefficient 0.005998271
# Minibatch at Epoch 7 batch 201 Train Dice Coefficient 6.2118174e-06 Test Dice Coefficient 0.00011658048
# Minibatch at Epoch 7 batch 211 Train Dice Coefficient 5.5210927e-05 Test Dice Coefficient 0.00549262
# Minibatch at Epoch 7 batch 221 Train Dice Coefficient 5.286264e-05 Test Dice Coefficient 1.3233646e-06
# Minibatch at Epoch 7 batch 231 Train Dice Coefficient 8.349897e-06 Test Dice Coefficient 0.00013176701
# Minibatch at Epoch 7 batch 241 Train Dice Coefficient 4.5783537e-08 Test Dice Coefficient 1.0256851e-05
# Minibatch at Epoch 7 batch 251 Train Dice Coefficient 0.00011817203 Test Dice Coefficient 0.00019057057
# Minibatch at Epoch 7 batch 261 Train Dice Coefficient 5.3859194e-06 Test Dice Coefficient 3.1346712e-08
# Minibatch at Epoch 7 batch 271 Train Dice Coefficient 3.4309098e-05 Test Dice Coefficient 9.081234e-06
# Minibatch at Epoch 7 batch 281 Train Dice Coefficient 6.171779e-05 Test Dice Coefficient 1.7993601e-08
# Minibatch at Epoch 7 batch 291 Train Dice Coefficient 0.00014875387 Test Dice Coefficient 0.00015177898
# -------------------------------------------------------------------------------------------------------
# After Epoch 7 Test Dice Coeff 6.673935e-05
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 8 batch 1 Train Dice Coefficient 7.532272e-05 Test Dice Coefficient 2.6929545e-06
# Minibatch at Epoch 8 batch 11 Train Dice Coefficient 6.8454005e-06 Test Dice Coefficient 1.892416e-05
# Minibatch at Epoch 8 batch 21 Train Dice Coefficient 0.00012710132 Test Dice Coefficient 1.9402607e-05
# Minibatch at Epoch 8 batch 31 Train Dice Coefficient 5.4171633e-06 Test Dice Coefficient 0.0013157753
# Minibatch at Epoch 8 batch 41 Train Dice Coefficient 0.0001168781 Test Dice Coefficient 0.00016293184
# Minibatch at Epoch 8 batch 51 Train Dice Coefficient 7.8757475e-06 Test Dice Coefficient 9.797487e-06
# Minibatch at Epoch 8 batch 61 Train Dice Coefficient 3.876239e-07 Test Dice Coefficient 4.449993e-06
# Minibatch at Epoch 8 batch 71 Train Dice Coefficient 0.00020820423 Test Dice Coefficient 3.4695752e-08
# Minibatch at Epoch 8 batch 81 Train Dice Coefficient 5.5009266e-08 Test Dice Coefficient 3.2735163e-05
# Minibatch at Epoch 8 batch 91 Train Dice Coefficient 8.42861e-05 Test Dice Coefficient 3.854181e-06
# Minibatch at Epoch 8 batch 101 Train Dice Coefficient 3.5038663e-06 Test Dice Coefficient 5.6797184e-05
# Minibatch at Epoch 8 batch 111 Train Dice Coefficient 0.00014346252 Test Dice Coefficient 4.0368622e-08
# Minibatch at Epoch 8 batch 121 Train Dice Coefficient 2.0153477e-05 Test Dice Coefficient 2.4487786e-06
# Minibatch at Epoch 8 batch 131 Train Dice Coefficient 5.2249234e-06 Test Dice Coefficient 1.6617731e-06
# Minibatch at Epoch 8 batch 141 Train Dice Coefficient 7.233172e-05 Test Dice Coefficient 0.00014858894
# Minibatch at Epoch 8 batch 151 Train Dice Coefficient 3.3361698e-06 Test Dice Coefficient 3.794511e-05
# Minibatch at Epoch 8 batch 161 Train Dice Coefficient 0.00023675135 Test Dice Coefficient 8.710959e-06
# Minibatch at Epoch 8 batch 171 Train Dice Coefficient 2.3150986e-05 Test Dice Coefficient 1.1313737e-05
# Minibatch at Epoch 8 batch 181 Train Dice Coefficient 4.639642e-08 Test Dice Coefficient 8.617811e-05
# Minibatch at Epoch 8 batch 191 Train Dice Coefficient 6.031231e-08 Test Dice Coefficient 0.00013572598
# Minibatch at Epoch 8 batch 201 Train Dice Coefficient 4.2177326e-05 Test Dice Coefficient 5.3452753e-05
# Minibatch at Epoch 8 batch 211 Train Dice Coefficient 4.36987e-06 Test Dice Coefficient 2.435194e-06
# Minibatch at Epoch 8 batch 221 Train Dice Coefficient 5.6180957e-05 Test Dice Coefficient 5.199731e-06
# Minibatch at Epoch 8 batch 231 Train Dice Coefficient 3.5150446e-05 Test Dice Coefficient 5.6513427e-06
# Minibatch at Epoch 8 batch 241 Train Dice Coefficient 6.763808e-05 Test Dice Coefficient 2.1577174e-08
# Minibatch at Epoch 8 batch 251 Train Dice Coefficient 2.967274e-05 Test Dice Coefficient 2.6417435e-08
# Minibatch at Epoch 8 batch 261 Train Dice Coefficient 2.695619e-05 Test Dice Coefficient 0.00011625752
# Minibatch at Epoch 8 batch 271 Train Dice Coefficient 2.5888704e-07 Test Dice Coefficient 3.2499947e-06
# Minibatch at Epoch 8 batch 281 Train Dice Coefficient 5.897608e-06 Test Dice Coefficient 2.6385604e-05
# Minibatch at Epoch 8 batch 291 Train Dice Coefficient 3.6183078e-06 Test Dice Coefficient 3.8011145e-05
# -------------------------------------------------------------------------------------------------------
# After Epoch 8 Test Dice Coeff 3.695488e-05
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 9 batch 1 Train Dice Coefficient 9.75993e-05 Test Dice Coefficient 0.00011550563
# Minibatch at Epoch 9 batch 11 Train Dice Coefficient 5.76846e-05 Test Dice Coefficient 0.00022618388
# Minibatch at Epoch 9 batch 21 Train Dice Coefficient 1.7681936e-06 Test Dice Coefficient 1.3698736e-05
# Minibatch at Epoch 9 batch 31 Train Dice Coefficient 0.00029214798 Test Dice Coefficient 0.00011463641
# Minibatch at Epoch 9 batch 41 Train Dice Coefficient 0.00022861801 Test Dice Coefficient 5.320096e-05
# Minibatch at Epoch 9 batch 51 Train Dice Coefficient 1.1037944e-05 Test Dice Coefficient 1.6708844e-05
# Minibatch at Epoch 9 batch 61 Train Dice Coefficient 1.2676291e-07 Test Dice Coefficient 5.645442e-05
# Minibatch at Epoch 9 batch 71 Train Dice Coefficient 3.225155e-06 Test Dice Coefficient 4.2157306e-05
# Minibatch at Epoch 9 batch 81 Train Dice Coefficient 2.6100495e-13 Test Dice Coefficient 7.700387e-05
# Minibatch at Epoch 9 batch 91 Train Dice Coefficient 1.0603683e-06 Test Dice Coefficient 0.00017539985
# Minibatch at Epoch 9 batch 101 Train Dice Coefficient 8.922458e-05 Test Dice Coefficient 1.3925212e-06
# Minibatch at Epoch 9 batch 111 Train Dice Coefficient 9.2984046e-05 Test Dice Coefficient 9.406666e-05
# Minibatch at Epoch 9 batch 121 Train Dice Coefficient 1.304212e-07 Test Dice Coefficient 9.376794e-05
# Minibatch at Epoch 9 batch 131 Train Dice Coefficient 3.6451665e-06 Test Dice Coefficient 1.6190845e-05
# Minibatch at Epoch 9 batch 141 Train Dice Coefficient 2.678037e-13 Test Dice Coefficient 0.0002980107
# Minibatch at Epoch 9 batch 151 Train Dice Coefficient 5.5813474e-05 Test Dice Coefficient 9.816976e-06
# Minibatch at Epoch 9 batch 161 Train Dice Coefficient 8.5497246e-05 Test Dice Coefficient 4.2770876e-05
# Minibatch at Epoch 9 batch 171 Train Dice Coefficient 1.3759481e-11 Test Dice Coefficient 8.801643e-06
# Minibatch at Epoch 9 batch 181 Train Dice Coefficient 0.00018932852 Test Dice Coefficient 0.00022523993
# Minibatch at Epoch 9 batch 191 Train Dice Coefficient 1.4810053e-06 Test Dice Coefficient 1.9183906e-05
# Minibatch at Epoch 9 batch 201 Train Dice Coefficient 1.2818092e-05 Test Dice Coefficient 4.6047285e-06
# Minibatch at Epoch 9 batch 211 Train Dice Coefficient 4.090613e-05 Test Dice Coefficient 1.01436835e-05
# Minibatch at Epoch 9 batch 221 Train Dice Coefficient 1.5665813e-05 Test Dice Coefficient 5.0590825e-05
# Minibatch at Epoch 9 batch 231 Train Dice Coefficient 2.116835e-05 Test Dice Coefficient 1.737609e-05
# Minibatch at Epoch 9 batch 241 Train Dice Coefficient 3.7143497e-08 Test Dice Coefficient 1.5895219e-05
# Minibatch at Epoch 9 batch 251 Train Dice Coefficient 7.5466314e-06 Test Dice Coefficient 1.9640287e-05
# Minibatch at Epoch 9 batch 261 Train Dice Coefficient 0.0003569586 Test Dice Coefficient 4.580227e-06
# Minibatch at Epoch 9 batch 271 Train Dice Coefficient 4.6189314e-08 Test Dice Coefficient 4.3001248e-05
# Minibatch at Epoch 9 batch 281 Train Dice Coefficient 0.00029947882 Test Dice Coefficient 9.264504e-06
# Minibatch at Epoch 9 batch 291 Train Dice Coefficient 1.09824626e-07 Test Dice Coefficient 5.5512446e-05
# -------------------------------------------------------------------------------------------------------
# After Epoch 9 Test Dice Coeff 1.4415445e-05
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 10 batch 1 Train Dice Coefficient 4.9220496e-05 Test Dice Coefficient 9.463646e-06
# Minibatch at Epoch 10 batch 11 Train Dice Coefficient 2.369059e-13 Test Dice Coefficient 6.022072e-10
# Minibatch at Epoch 10 batch 21 Train Dice Coefficient 1.63759e-05 Test Dice Coefficient 5.5454682e-05
# Minibatch at Epoch 10 batch 31 Train Dice Coefficient 2.6773215e-13 Test Dice Coefficient 3.608533e-05
# Minibatch at Epoch 10 batch 41 Train Dice Coefficient 2.3348044e-05 Test Dice Coefficient 5.3375923e-05
# Minibatch at Epoch 10 batch 51 Train Dice Coefficient 1.1271036e-05 Test Dice Coefficient 2.0701495e-05
# Minibatch at Epoch 10 batch 61 Train Dice Coefficient 0.00029910635 Test Dice Coefficient 5.43812e-05
# Minibatch at Epoch 10 batch 71 Train Dice Coefficient 1.25398765e-05 Test Dice Coefficient 1.2222469e-05
# Minibatch at Epoch 10 batch 81 Train Dice Coefficient 6.865739e-05 Test Dice Coefficient 8.2086635e-06
# Minibatch at Epoch 10 batch 91 Train Dice Coefficient 4.2797925e-09 Test Dice Coefficient 1.5043678e-05
# Minibatch at Epoch 10 batch 101 Train Dice Coefficient 4.8109396e-05 Test Dice Coefficient 1.2223852e-07
# Minibatch at Epoch 10 batch 111 Train Dice Coefficient 1.9295683e-06 Test Dice Coefficient 0.0001679261
# Minibatch at Epoch 10 batch 121 Train Dice Coefficient 3.0115302e-06 Test Dice Coefficient 1.9808913e-05
# Minibatch at Epoch 10 batch 131 Train Dice Coefficient 2.0424235e-05 Test Dice Coefficient 0.00023994484
# Minibatch at Epoch 10 batch 141 Train Dice Coefficient 6.2895833e-06 Test Dice Coefficient 0.00011427836
# Minibatch at Epoch 10 batch 151 Train Dice Coefficient 1.1855583e-06 Test Dice Coefficient 4.2680538e-05
# Minibatch at Epoch 10 batch 161 Train Dice Coefficient 4.6332067e-07 Test Dice Coefficient 0.0041652513
# Minibatch at Epoch 10 batch 171 Train Dice Coefficient 3.6354616e-06 Test Dice Coefficient 4.1443272e-08
# Minibatch at Epoch 10 batch 181 Train Dice Coefficient 3.643032e-05 Test Dice Coefficient 5.9831917e-10
# Minibatch at Epoch 10 batch 191 Train Dice Coefficient 5.4709286e-05 Test Dice Coefficient 9.0982585e-06
# Minibatch at Epoch 10 batch 201 Train Dice Coefficient 3.58362e-05 Test Dice Coefficient 9.32262e-10
# Minibatch at Epoch 10 batch 211 Train Dice Coefficient 3.6799163e-05 Test Dice Coefficient 0.00023063592
# Minibatch at Epoch 10 batch 221 Train Dice Coefficient 7.153232e-08 Test Dice Coefficient 4.9350883e-06
# Minibatch at Epoch 10 batch 231 Train Dice Coefficient 0.00014191474 Test Dice Coefficient 0.0002325793
# Minibatch at Epoch 10 batch 241 Train Dice Coefficient 5.641206e-05 Test Dice Coefficient 2.1773129e-05
# Minibatch at Epoch 10 batch 251 Train Dice Coefficient 3.034519e-07 Test Dice Coefficient 1.9137236e-05
# Minibatch at Epoch 10 batch 261 Train Dice Coefficient 8.834187e-05 Test Dice Coefficient 4.908864e-08
# Minibatch at Epoch 10 batch 271 Train Dice Coefficient 0.0003357047 Test Dice Coefficient 4.285815e-05
# Minibatch at Epoch 10 batch 281 Train Dice Coefficient 5.443046e-05 Test Dice Coefficient 4.1602203e-08
# Minibatch at Epoch 10 batch 291 Train Dice Coefficient 2.394512e-08 Test Dice Coefficient 0.0003376442
# -------------------------------------------------------------------------------------------------------
# After Epoch 10 Test Dice Coeff 9.124617e-06
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 11 batch 1 Train Dice Coefficient 0.00018456034 Test Dice Coefficient 3.595261e-05
# Minibatch at Epoch 11 batch 11 Train Dice Coefficient 7.298007e-05 Test Dice Coefficient 5.5288336e-05
# Minibatch at Epoch 11 batch 21 Train Dice Coefficient 7.292144e-05 Test Dice Coefficient 3.2525224e-06
# Minibatch at Epoch 11 batch 31 Train Dice Coefficient 6.6194234e-06 Test Dice Coefficient 9.178142e-06
# Minibatch at Epoch 11 batch 41 Train Dice Coefficient 2.9903642e-08 Test Dice Coefficient 1.9182107e-05
# Minibatch at Epoch 11 batch 51 Train Dice Coefficient 2.6819505e-13 Test Dice Coefficient 1.8499015e-05
# Minibatch at Epoch 11 batch 61 Train Dice Coefficient 0.000327181 Test Dice Coefficient 0.00012294932
# Minibatch at Epoch 11 batch 71 Train Dice Coefficient 5.833245e-06 Test Dice Coefficient 7.966797e-05
# Minibatch at Epoch 11 batch 81 Train Dice Coefficient 2.5367532e-05 Test Dice Coefficient 9.560853e-06
# Minibatch at Epoch 11 batch 91 Train Dice Coefficient 2.0143636e-06 Test Dice Coefficient 1.1778319e-07
# Minibatch at Epoch 11 batch 101 Train Dice Coefficient 7.472813e-05 Test Dice Coefficient 0.00029863365
# Minibatch at Epoch 11 batch 111 Train Dice Coefficient 4.389221e-05 Test Dice Coefficient 1.18024005e-07
# Minibatch at Epoch 11 batch 121 Train Dice Coefficient 7.812078e-05 Test Dice Coefficient 2.2857932e-06
