# %% [markdown]
# """
# COMPLETELY NEW VERSION OF UNET DESIGNED FOR BRAIN TUMOUR SEGMENTATION
#
#
# residual network in each convolutional block
#
# SPECS:
#
# 1. Input size  is 240x240x4 for each image
#
# 2. BRATS dataset
#
# 3. DICE LOSS IS TAKEN AS A LOSS FUNCTION
#
# 4. MULTICLASS SEGMENTATION HAS BEEN IMPLEMENTED
#
#
# DESC:
#
# HERE OUR PREDICTION WILL HAVE 4 DIMENSIONS(because we have 4 classes) FOR EACH IMAGE. THESE 4 PREDICTIONS are compared with hot encoded label(Ground truth)
# THIS IN A WAY TRAINS THE SYSTEM TO HOT ENCODE THE PREDICTIONS TOO.
# WE ARE TRYING TO IMPLEMENT THE ABOVE STATED MODEL TO IMPLEMENT MULTICLASS SEGEMENTATION. BUT HAD TO CHANGE SOME THINGS WHICH ARE STATED BELOW
#
# PROBLEMS AND CHANGES:
#
# 1. Faced the problem of class imbalance. So in this version we multiply dice coefficient for each class with certain weight. this weight is reciprocal of the frequency of that class
#
# 2. The problem of class imbalance still persists and dice coeff is more than 1. So i this version we have implemented a new dice coefficient function.
#
#
# FUTURE:
#
# 1. IMPROVING DICE COEFFICIENT
#
# 2. 3D IMPLEMENTATION

# %%
'''Mounting Google Drive on the Colab notebook'''
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#file_image = '/content/gdrive/My Drive/Brain_Tumour_segmentation/Train_image.hdf5'
import h5py
#dataset has data of 484 patients. (155 images of each patient)
#data is extracted using 4 different techniques
#size of data of 1 patient is [240,240,155,4]
#for 2D segmentation we stack in 3rd dimension (axis=2)
#train_image
image_store = h5py.File("/content/gdrive/My Drive/Brain_Tumour_segmentation/Train_image.hdf5", "r")
#train_labels
label_store = h5py.File("/content/gdrive/My Drive/Brain_Tumour_segmentation/Train_label.hdf5", "r")
train_images = image_store["image"]
train_labels = label_store["label"]
#print('hi')

# %%
'''IMPORTING LIBRARIES'''
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
import time
import math
'''Clearing tesorflow computation graph'''
tf.reset_default_graph()

# %%
'''DEFINING VARIABLES'''

batch_size=100              #batch size taken at a time
n_class = 4                #number of classes in the label

'''PLACEHOLDER for input and output of UNET'''
X = tf.placeholder(shape=[None,240,240,4], dtype=tf.float32, name='input_image')
y = tf.placeholder(shape=[240,240,None,1], dtype=tf.int64, name='hot_encode_label')


'''Batch variable exraction from h5py file (used by functions 'rnadom_h5py_batch' and 'test_batch')'''
out_img = np.empty((240,240,batch_size,4),dtype=np.float32)
out_label = np.empty((240,240,batch_size,1),dtype=np.int64)

# %% [markdown]
# DEFINING ALL THE REQUIRED FUNCTIONS

# %%
'''COMPUTATION GRAPH Function Definitions'''


def left_filter_def(ker_size,in_chan,out_chan,name='left_filter'):
    '''Defining a filter variable to perform convolution'''
    stddev = np.sqrt(4/(ker_size*ker_size*ker_size*in_chan*out_chan))           #HE initialization
    if stddev < 0.001:
        stddev = 0.001
    return (tf.Variable(tf.truncated_normal([ker_size,ker_size,in_chan,out_chan],stddev=stddev),name=name))


def right_filter_def(ker_size,in_chan,out_chan,name='right_filter'):
    '''Defining a filter variable to perform transpose convolution'''
    stddev = np.sqrt(4/(ker_size*ker_size*ker_size*in_chan*out_chan))
    if stddev < 0.001:
        stddev = 0.001
    return (tf.Variable(tf.truncated_normal([ker_size,ker_size,out_chan,in_chan],stddev=stddev),name=name))


def Conv_layer(input_im,filter_mask,stride,activation='None',name='conv'):
    '''Function to perform Convolution and apply activation filter'''
    '''Convolution'''
    conv = tf.nn.conv2d(input_im,filter_mask,strides = [1,stride,stride,1], padding = "SAME",name=name)
    #norm_conv = tf.layers.batch_normalization(conv, training=training, momentum=0.9)
    '''Activation'''
    if activation == 'relu':
        return(tf.nn.relu(conv))
    elif activation == 'softmax':
        return(tf.nn.softmax(conv,axis=-1))
    elif activation == 'elu':
        return(tf.nn.elu(conv))
    else:
        #activation == 'None'
        return(conv)
    

def Deconv_layer(input_im,filter_mask,stride,activation='None',name='De_conv'):
    '''Function to perform Transpose Convolution and apply activation filter'''
    '''Transpose Convolution'''
    inp_shape = np.shape(input_im) #tf.shape()
    out_shape = [batch_size]+[int(inp_shape[1].value*2), int(inp_shape[2].value*2), int(inp_shape[3].value/2)]
    
    conv = tf.nn.conv2d_transpose(input_im, filter_mask, out_shape, strides = [1,stride,stride,1], padding = "SAME",name=name)
    #norm_conv = tf.layers.batch_normalization(conv, training=training, momentum=0.9)
    '''Activation'''
    if activation == 'relu':
        return(tf.nn.relu(conv))
    elif activation == 'softmax':
        return(tf.nn.softmax(conv,axis=-1))
    elif activation == 'elu':
        return(tf.nn.elu(conv))
    else:
        #activation == 'None'
        return(conv)

# %%
'''Functions for batch Extraction and pre processing'''

def normalizing_input():
    '''normalization of each input channels'''
    global out_img
    '''CHANNEL INFO'''
    # maximum value found using function called "Finding_maximum_to_normalise "
    #'''max value for dimension 4 is 5337.0'''
    #'''max value for dimension 3 is 11737.0'''
    #'''max value for dimension 2 is 9751.0'''
    #'''max value for dimension 1 is 6476.0'''
    out_img[:,:,:,0] = out_img[:,:,:,0]/6476.0
    out_img[:,:,:,1] = out_img[:,:,:,1]/9751.0
    out_img[:,:,:,2] = out_img[:,:,:,2]/11737.0
    out_img[:,:,:,3] = out_img[:,:,:,3]/5337.0




def random_h5py_batch(current_batch_no,permute_mat):
    '''Function to take batches randomly'''
    global out_img
    global out_label
    
    '''training info'''
    train_info = 300*155  #100 patients with 155 images each

    if current_batch_no == 0:
        no_of_batches = train_info//batch_size  
        permute_mat = np.random.permutation(no_of_batches)
    
    start = permute_mat[current_batch_no]*batch_size
    end = start + batch_size
    train_images.read_direct(out_img,np.s_[:,:,start:end,:])
    train_labels.read_direct(out_label,np.s_[:,:,start:end,:])
    current_batch_no += 1
    #print(len(out_img))
    '''Input normalization'''
    normalizing_input()
    '''normalization oof labels'''
    #out_label = out_label
    '''converting multi class to dual class'''
    #out_label = convert_dual_class(out_label)
    
    '''Rolling axes'''
    out_img_send = np.rollaxis(out_img,2, 0)
    '''hot encoding'''
    out_label_send = out_label
    
    last=0
    if current_batch_no == len(permute_mat):
        last=1
    
    return (out_img_send,out_label_send,current_batch_no,permute_mat,last)


def test_batch():
    '''Function to take next test batch'''
    
    global out_img
    global out_label
    
    '''training and testing info'''
    train_info = 300*155  #100 patients with 155 images each
    test_info = 184*155  #100 patients with 155 images each
    
    no_of_batches = test_info//batch_size  
    permute_mat = np.random.permutation(no_of_batches)
    start = (permute_mat[0]*batch_size) +train_info
    end = start + batch_size
    train_images.read_direct(out_img,np.s_[:,:,start:end,:])
    train_labels.read_direct(out_label,np.s_[:,:,start:end,:])
    
    '''normalization'''
    normalizing_input()
    '''Converting multiclass to dual class'''
    #out_label = convert_dual_class(out_label) 
    '''rolling axis'''
    out_img_send = np.rollaxis(out_img,2, 0)
    '''hot encoding'''
    out_label_send = (out_label)
    
    return (out_img_send,out_label_send)

# %% [markdown]
# INITIALIZING THE MODEL FILTERS
#
#
# Filters with Resnet modifications

# %%
  
def hot_encode(check_image,depth=n_class,name='hot_encode'):
    '''function for hot encoding images'''
    a = tf.one_hot(indices = check_image, depth=depth,name=name)
    b = tf.transpose(a,perm=[2,0,1,4,3])
    return b


#############################################################################################################################
#GENERALIZED DICE LOSS FUNCTION
#############################################################################################################################
def generalized_dice_coeff(y_true, y_pred):
    Ncl = y_pred.shape[-1]
    w = np.zeros(shape=(Ncl,))
    w = tf.reduce_sum(y_true, axis=[0,1,2]) + 1
    w = 1/((w**2))
    print(np.shape(w))
    # Compute gen dice coef:
    numerator = y_true*y_pred
    denominator = y_true+y_pred
    a=b=0
    for i in range(np.shape(w)[0]):
        a += w[i]*numerator[:,:,:,i]
        b += w[i]*denominator[:,:,:,i]
            
    num = tf.reduce_sum(a)
    den = tf.reduce_sum(b)

    gen_dice_coef = 2*(num/den)

    return (1-gen_dice_coef)
  
#############################################################################################################################
#GENERALIZED FOCAL LOSS FUNCTION
#############################################################################################################################
def generalized_focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    
    Ncl = y_pred.shape[-1]
    w = np.zeros(shape=(Ncl,))
    w = tf.reduce_sum(y_true, axis=[0,1,2]) + 1
    w = 1/((w))
    y_pred = y_pred + 0.000000001                                               #to ensure that logarithm in next step doenst give math error
    
    ce = tf.multiply(y_true, -tf.log(y_pred))                                   #cross entropy (multiclass)
    fl_var = tf.multiply(y_true, tf.pow(tf.subtract(1., y_pred), gamma))        #focal loss variables (gamma*(1-pt)*(graund_truth))
    #fl = tf.multiply(alpha, tf.multiply(fl_var, ce))
    fl = tf.multiply(fl_var, ce)
    #fl=ce
    normalized_focal = 0
    
    for i in range(np.shape(w)[0]):
        #print(i)
        a = w[i]#/tf.reduce_sum(w)
        b = fl[:,:,:,i]
        #c = (b)/(tf.reduce_max(b)+1)
        normalized_focal += tf.reduce_sum(a*b)
        #b += w[i]*denominator[:,:,:,i]
    weighted_focal = normalized_focal/4
    return (weighted_focal)

#############################################################################################################################
#MEAN SQUARE ERROR(MSE) FUNCTION
#############################################################################################################################
def diff_error(y_true, y_pred):
    error = tf.square(y_true-y_pred)
    error = (error+0.00000000001-tf.reduce_min(error))/(tf.reduce_max(error)+0.0000001-tf.reduce_min(error))
    return tf.reduce_mean(error)

# %%
def find_hybrid_loss(y_true,y_pred,gamma=0.6,alpha=0.5):
    dice = generalized_dice_coeff(y_true, y_pred)
    focal = generalized_focal_loss(y_true, y_pred)
    MeanAndSquare = diff_error(y_true, y_pred)
    hybrid = (gamma*dice)+((1-gamma)*((alpha*focal)+((1-alpha)*MeanAndSquare)))
    return hybrid,dice,focal,MeanAndSquare

# %%
'''MODEL1 Filter definition'''
'''LEFT'''

filter1 = left_filter_def(3,4,8,name='filter1')
filter2 = left_filter_def(3,8,8,name='filter2')
filter3 = left_filter_def(3,8,8,name='filter3')
filter4 = left_filter_def(3,8,8,name='filter4')

filter5 = left_filter_def(3,8,16,name='filter5')
filter6 = left_filter_def(3,16,16,name='filter6')
filter7 = left_filter_def(3,16,16,name='filter7')
filter8 = left_filter_def(3,16,16,name='filter8')

filter9 = left_filter_def(3,16,32,name='filter9')
filter10= left_filter_def(3,32,32,name='filter10')
filter11= left_filter_def(3,32,32,name='filter11')
filter12= left_filter_def(3,32,32,name='filter12')

filter13= left_filter_def(3,32,64,name='filter13')
filter14= left_filter_def(3,64,64,name='filter14')
filter15= left_filter_def(3,64,64,name='filter15')
filter16= left_filter_def(3,64,64,name='filter16')

filter17= left_filter_def(3,64,128,name='filter17')
filter18= left_filter_def(3,128,128,name='filter18')
filter19= left_filter_def(3,128,64,name='filter19')

'''RIGHT'''

filter20= right_filter_def(3,128,64,name='filter20')
depth_filter1 = left_filter_def(1,(2*64),64,name='depth_filter1')
filter21= left_filter_def(3,64,64,name='filter21')
filter22= left_filter_def(3,64,64,name='filter22')
filter23= left_filter_def(3,64,32,name='filter23')

filter24= right_filter_def(3,64,32,name='filter24')
depth_filter2 = left_filter_def(1,(2*32),32,name='depth_filter2')
filter25= left_filter_def(3,32,32,name='filter25')
filter26= left_filter_def(3,32,32,name='filter26')
filter27= left_filter_def(3,32,16,name='filter27')

filter28= right_filter_def(3,32,16,name='filter28')
depth_filter3 = left_filter_def(1,(2*16),16,name='depth_filter3')
filter29= left_filter_def(3,16,16,name='filter29')
filter30= left_filter_def(3,16,16,name='filter30')
filter31= left_filter_def(3,16,8,name='filter31')

filter32= right_filter_def(3,16,8,name='filter32')
depth_filter4 = left_filter_def(1,(2*8),8,name='depth_filter4')
filter33= left_filter_def(3,8,8,name='filter33')
filter34= left_filter_def(3,8,8,name='filter34')
filter35= left_filter_def(3,8,n_class,name='filter35')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# DEFINING THE MODEL STRUCTURE
#
# Model with Resnet Modification

# %%
def predict_model1(X):
    '''Function to define the UNET model'''
    with tf.name_scope("BLOCK1"):
        '''BLOCK1'''
        CNN1 = Conv_layer(X,filter1,stride=1,activation='relu',name='CNN1')
        #rint ("CNN1",np.shape(CNN1))
        CNN2 = Conv_layer(CNN1,filter2,stride=1,activation='relu',name='CNN2')
        #rint ("CNN2",np.shape(CNN2))
        CNN3 = Conv_layer(CNN2,filter3,stride=1,activation='relu',name='CNN3')
        CNNR1 = tf.add(Conv_layer(CNN3,filter4,stride=1,activation='relu',name='CNNR1'), (CNN1+CNN2), name='Resnet1')
        #rint ("CNNR1",np.shape(CNNR1))
        pool1 = tf.nn.max_pool(CNNR1,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID',name='POOL1')
    
    with tf.name_scope("BLOCK2"):
        '''BLOCK2'''
        CNN4 = Conv_layer(pool1,filter5,stride=1,activation='relu',name='CNN4')
        #rint ("CNN3",np.shape(CNN3))
        CNN5 = Conv_layer(CNN4,filter6,stride=1,activation='relu',name='CNN5')
        #rint ("CNN4",np.shape(CNN4))
        CNN6 = Conv_layer(CNN5,filter7,stride=1,activation='relu',name='CNN6')
        CNNR2 = tf.add(Conv_layer(CNN6,filter8,stride=1,activation='relu',name='CNNR2'), (CNN4+CNN5), name='Resnet2')
        #rint ("CNNR2",np.shape(CNNR2))
        pool2 = tf.nn.max_pool(CNNR2,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID',name='POOL2')
    
    with tf.name_scope("BLOCK3"):
        '''BLOCK3'''
        CNN7 = Conv_layer(pool2,filter9,stride=1,activation='relu',name='CNN7')
        #rint ("CNN5",np.shape(CNN5))
        CNN8 = Conv_layer(CNN7,filter10,stride=1,activation='relu',name='CNN8')
        #rint ("CNN6",np.shape(CNN6))
        CNN9 = Conv_layer(CNN8,filter11,stride=1,activation='relu',name='CNN9')
        CNNR3 = tf.add(Conv_layer(CNN9,filter12,stride=1,activation='relu',name='CNNR3'), (CNN7+CNN8), name='Resnet3')
        #rint ("CNNR3N",np.shape(CNNR3))
        pool3 = tf.nn.max_pool(CNNR3,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID',name='POOL3')
    
    with tf.name_scope("BLOCK4"):
        '''BLOCK4'''
        CNN10= Conv_layer(pool3,filter13,stride=1,activation='relu',name='CNN10')
        #rint ("CNN7",np.shape(CNN7))
        CNN11= Conv_layer(CNN10,filter14,stride=1,activation='relu',name='CNN11')
        #rint ("CNN8",np.shape(CNN8))
        CNN12 = Conv_layer(CNN11,filter15,stride=1,activation='relu',name='CNN12')
        CNNR4 = tf.add(Conv_layer(CNN12,filter16,stride=1,activation='relu',name='CNNR4'), (CNN10+CNN11), name='Resnet4')
        #rint ("CNNR4",np.shape(CNNR4))
        pool4 = tf.nn.max_pool(CNNR4,ksize=[1,2,2,1],strides=[1,2,2,1],padding='VALID',name='POOL4')
    
    with tf.name_scope("BLOCK5"):
        '''BLOCK5'''
        CNN13 = Conv_layer(pool4,filter17,stride=1,activation='relu',name='CNN13')
        #rint ("CNN9",np.shape(CNN9))
        CNN14 = Conv_layer(CNN13,filter18,stride=1,activation='relu',name='CNN14')
        #rint ("CNN10",np.shape(CNN10))
        CNN15 = Conv_layer(CNN14,filter19,stride=1,activation='relu',name='CNN15')
        #NNR5 = tf.add(Conv_layer(CNN10,filter15,stride=1,activation='relu',name='CNNR5'), CNN9, name='Resnet5')
        #rint ("CNNR5",np.shape(CNNR5))
    
    '''Moving UP'''
    
    with tf.name_scope("BLOCK6"):
        '''BLOCK6'''
        concat1 = tf.concat([CNN15,pool4],axis=3,name='CONCAT1')
        #rint ("concat1",np.shape(concat1))
        DCNN1= Deconv_layer(concat1,filter20,stride=2,activation='relu',name='DE_CONV1')
        #rint ("DCNN1",np.shape(DCNN1))
        
        CNN11 = Conv_layer(DCNN1,filter21,stride=1,activation='relu',name='CNN11')
        depth_CNN1 = Conv_layer(tf.concat([CNN11,CNNR4],axis=3),depth_filter1,stride=1,activation='relu',name='DepthCNN1') 
        #rint ("CNN11",np.shape(CNN11))
        CNNR6 = tf.add(Conv_layer(depth_CNN1,filter22,stride=1,activation='relu',name='CNNR6'), DCNN1, name='Resnet6')
        #rint ("CNNR6",np.shape(CNNR6))
        CNN12 = Conv_layer(CNNR6,filter23,stride=1,activation='relu',name='CNN12')
        #rint ("CNN12",np.shape(CNN12))
    
    with tf.name_scope("BLOCK7"):
        '''BLOCK7'''
        concat2 = tf.concat([CNN12,pool3],axis=3,name='CONCAT2')
        #rint ("concat2",np.shape(concat2))
        DCNN2= Deconv_layer(concat2,filter24,stride=2,activation='relu',name='DE_CONV2')
        #rint ("DCNN2",np.shape(DCNN2))
        
        CNN13 = Conv_layer(DCNN2,filter25,stride=1,activation='relu',name='CNN13')
        depth_CNN2 = Conv_layer(tf.concat([CNN13,CNNR3],axis=3),depth_filter2,stride=1,activation='relu',name='DepthCNN12')
        #rint ("CNN13",np.shape(CNN13))
        CNNR7 = tf.add(Conv_layer(depth_CNN2,filter26,stride=1,activation='relu',name='CNNR7'), DCNN2, name='Resnet7')
        #rint ("CNNR7",np.shape(CNNR7))
        CNN14 = Conv_layer(CNNR7,filter27,stride=1,activation='relu',name='CNN14')
        #rint ("CNN14",np.shape(CNN14))
    
    with tf.name_scope("BLOCK8"):
        '''BLOCK8'''
        concat3 = tf.concat([CNN14,pool2],axis=3,name='CONCAT3')
        #rint ("concat3",np.shape(concat3))
        DCNN3= Deconv_layer(concat3,filter28,stride=2,activation='relu',name='DE_CONV3')
        #rint ("DCNN3",np.shape(DCNN3))
        
        CNN15 = Conv_layer(DCNN3,filter29,stride=1,activation='relu',name='CNN15')
        depth_CNN3 = Conv_layer(tf.concat([CNN15,CNNR2],axis=3),depth_filter3,stride=1,activation='relu',name='DepthCNN12')
        #rint ("CNN15",np.shape(CNN15))
        CNNR8 = tf.add(Conv_layer(depth_CNN3,filter30,stride=1,activation='relu',name='CNNR8'), DCNN3, name='Resnet8')
        #rint ("CNNR8",np.shape(CNNR8))
        CNN16 = Conv_layer(CNNR8,filter31,stride=1,activation='relu',name='CNN16')
        #rint ("CNN16",np.shape(CNN16))
         
    with tf.name_scope("BLOCK9"):
        '''BLOCK9'''
        concat4 = tf.concat([CNN16,pool1],axis=3,name='CONCAT4')
        #rint ("concat4",np.shape(concat4))
        DCNN4= Deconv_layer(concat4,filter32,stride=2,activation='relu',name='DE_CONV4')
        #rint ("DCNN4",np.shape(DCNN4))
        
        CNN17 = Conv_layer(DCNN4,filter33,stride=1,activation='relu',name='CNN17')
        depth_CNN4 = Conv_layer(tf.concat([CNN17,CNNR1],axis=3),depth_filter4,stride=1,activation='relu',name='DepthCNN12')
        #rint ("CNN17",np.shape(CNN17))
        CNNR9 = tf.add(Conv_layer(depth_CNN4,filter34,stride=1,activation='relu',name='CNNR8'), DCNN4, name='Resnet9')
        #rint ("CNNR9",np.shape(CNNR9))
        CNN18 = Conv_layer(CNNR9,filter35,stride=1,activation='softmax',name='CNN18')
        #rint ("CNN18",np.shape(CNN18))
    return (CNN18)

# = (predict_model1(X))

# %%
def train_unet(learning_rate =0.0001,n_epochs = 100):
    '''Function to Train U-Net'''
    prediction = predict_model1(X)#logits
    '''----------------------------------------------------------------------------------------------------------------------------------------------------------------'''
    with tf.name_scope("LOSS_FUNCTION"):
        '''using multi dimensional dice'''
        hot_y = hot_encode(y)
        #dice = 1+ dice_coef_multilabel(hot_y,prediction)     #dice loss for verison 1
        #dice = generalized_dice_coeff(hot_y[:,:,:,:,0], prediction)
        #focal = generalized_focal_loss(hot_y[:,:,:,:,0], prediction)
        hybrid,dice,focal,mean_error = find_hybrid_loss(hot_y[:,:,:,:,0], prediction, gamma=0.78,alpha=0.8)
        #mean_error = diff_error(hot_y[:,:,:,:,0], prediction)
    '''----------------------------------------------------------------------------------------------------------------------------------------------------------------'''
    with tf.name_scope("COST_FUNCTION"):
        '''Cost function''''''Remember to change max to min min to mx depending on loss function'''
        loss = tf.reduce_mean(hybrid, name="loss")

    with tf.name_scope("OPTIMIZER"):
        '''Optimizer'''
        optimize = tf.train.AdamOptimizer(learning_rate = learning_rate)
        training_output = optimize.minimize(loss)


    '''initializing'''
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()

    '''Timing'''
    start = time.time()
    '''Session'''
    gpu_option = tf.GPUOptions(per_process_gpu_memory_fraction=0.5)
    with tf.Session(config=tf.ConfigProto(gpu_options=gpu_option)) as sess:
        init.run()
        for epoch in range(n_epochs):
            current_batch_no = 0
            permute_mat = 0
            iteration = 0
            while(1):
                #with tf.device('/cpu:0'):
                epoch_x,epoch_y,current_batch_no,permute_mat,last = random_h5py_batch(current_batch_no,permute_mat)
                sess_results = sess.run(training_output, feed_dict={X: epoch_x, y: epoch_y})
                #print ("epoch",epoch+1,"batch",iteration+1)#,"Cost",sess_results[0])
            
                '''DICE Coefficient for iteration'''
                #with tf.device('/cpu:0'):
                if iteration%10==0:
                    acc_train = 1-(hybrid.eval(feed_dict={X: epoch_x, y: epoch_y}))
                    test_images, test_labels = test_batch()
                    acc_test = 1-(hybrid.eval(feed_dict={X: test_images, y: test_labels}))
                    print("Minibatch at","Epoch", epoch+1,"batch",iteration+1, "Train accuracy:", acc_train, "Test accuracy:", acc_test)
                if last ==1:
                    break
                iteration +=1
            test_images, test_labels = test_batch()
            hybrid_test,dice_test,focal_test,diff_test = sess.run([hybrid,dice,focal,mean_error], feed_dict={X: test_images, y: test_labels})
            #diff_test = sess.run(mean_error, feed_dict={X: test_images, y: test_labels})
            print("-------------------------------------------------------------------------------------------------------")
            print("After Epoch", epoch+1, "Hybrid Test accuracy:", 1-hybrid_test, "Dice Test accuracy:", 1-dice_test, "Focal Test accuracy:", 1-focal_test, "MSE Test accuracy:", 1-diff_test)
            #print("mse",1-diff_test)
            print("-------------------------------------------------------------------------------------------------------")
        
        
            if epoch % 1 == 0:
                test_example =   test_images
                test_example_gt = np.rollaxis(test_labels,2,0)
                sess_results = sess.run(prediction,feed_dict={X:test_example})
                
                sess_results = sess_results[0,:,:,1] + (2*sess_results[0,:,:,2]) + (3*sess_results[0,:,:,3])
                test_example = test_example[0,:,:,3]
                test_example_gt = test_example_gt[0,:,:,:]
                
                plt.figure()
                plt.imshow(np.squeeze(test_example),cmap='gray')
                plt.axis('off')
                plt.title('Original Image')
                plt.savefig('/content/gdrive/My Drive/Brain_Tumour_segmentation/loss_functions_testing/Resnet_with_3_loss/'+str(epoch)+"a_Original_Image.png")
                       
                        
                plt.figure()
                plt.imshow(np.squeeze(test_example_gt),cmap='gray')
                plt.axis('off')
                plt.title('Ground Truth Mask')
                plt.savefig('/content/gdrive/My Drive/Brain_Tumour_segmentation/loss_functions_testing/Resnet_with_3_loss/'+str(epoch)+"b_Original_Mask.png")
                
                plt.figure()
                plt.imshow(np.squeeze(sess_results),cmap='gray')
                plt.axis('off')
                plt.title('Generated Mask')
                plt.savefig('/content/gdrive/My Drive/Brain_Tumour_segmentation/loss_functions_testing/Resnet_with_3_loss/'+str(epoch)+"c_Generated_Mask.png")

                plt.close('all')

        '''Saving the graph'''
        save_path = saver.save(sess, "/content/gdrive/My Drive/Brain_Tumour_segmentation/loss_functions_testing/final_madel_graph")
    end = time.time()
    total_time = end-start
    return (total_time)

# %% [markdown]
# COMMENTS ON DICE LOSS AND ACCURACY
#
# 1. Under the name_scope "LOSS FUNCTION", the variable named dice corresponds to dice loss and since the function dice_multipleclass() returns a value between -1 and 0(both included) , we add 1. Also another reason for this is there is no maximize function in adam optimizer(or any other optimizing function).
#
# 2. While printing  the accuracy (everywhere)  we have to print dice coefficient and not dice loss therefore we add 1 to the dice_loss calculation

# %%
train_unet()
# Out:
# (4,)
# Minibatch at Epoch 1 batch 1 Train accuracy: 0.08020031452178955 Test accuracy: 0.08126318454742432
# Minibatch at Epoch 1 batch 11 Train accuracy: 0.0749470591545105 Test accuracy: 0.07543951272964478
# Minibatch at Epoch 1 batch 21 Train accuracy: 0.07191097736358643 Test accuracy: 0.07226383686065674
# Minibatch at Epoch 1 batch 31 Train accuracy: 0.07458323240280151 Test accuracy: 0.07494944334030151
# Minibatch at Epoch 1 batch 41 Train accuracy: 0.07256042957305908 Test accuracy: 0.1405860185623169
# Minibatch at Epoch 1 batch 51 Train accuracy: 0.07368600368499756 Test accuracy: 0.07397782802581787
# Minibatch at Epoch 1 batch 61 Train accuracy: 0.07838177680969238 Test accuracy: 0.07332539558410645
# Minibatch at Epoch 1 batch 71 Train accuracy: 0.07312047481536865 Test accuracy: 0.07235544919967651
# Minibatch at Epoch 1 batch 81 Train accuracy: 0.07499969005584717 Test accuracy: 0.07551735639572144
# Minibatch at Epoch 1 batch 91 Train accuracy: 0.07653653621673584 Test accuracy: 0.07890737056732178
# Minibatch at Epoch 1 batch 101 Train accuracy: 0.10666370391845703 Test accuracy: 0.0727165937423706
# Minibatch at Epoch 1 batch 111 Train accuracy: 0.07259339094161987 Test accuracy: 0.07232320308685303
# Minibatch at Epoch 1 batch 121 Train accuracy: 0.07356297969818115 Test accuracy: 0.07237911224365234
# Minibatch at Epoch 1 batch 131 Train accuracy: 0.10735189914703369 Test accuracy: 0.07317781448364258
# Minibatch at Epoch 1 batch 141 Train accuracy: 0.0770348310470581 Test accuracy: 0.07523328065872192
# Minibatch at Epoch 1 batch 151 Train accuracy: 0.08442097902297974 Test accuracy: 0.0808858871459961
# Minibatch at Epoch 1 batch 161 Train accuracy: 0.13710397481918335 Test accuracy: 0.09188824892044067
# Minibatch at Epoch 1 batch 171 Train accuracy: 0.14064878225326538 Test accuracy: 0.09088486433029175
# Minibatch at Epoch 1 batch 181 Train accuracy: 0.09775108098983765 Test accuracy: 0.08464807271957397
# Minibatch at Epoch 1 batch 191 Train accuracy: 0.08211284875869751 Test accuracy: 0.10502469539642334
# Minibatch at Epoch 1 batch 201 Train accuracy: 0.10191214084625244 Test accuracy: 0.11101371049880981
# Minibatch at Epoch 1 batch 211 Train accuracy: 0.09352529048919678 Test accuracy: 0.10222232341766357
# Minibatch at Epoch 1 batch 221 Train accuracy: 0.09607887268066406 Test accuracy: 0.10088342428207397
# Minibatch at Epoch 1 batch 231 Train accuracy: 0.09203702211380005 Test accuracy: 0.09898757934570312
# Minibatch at Epoch 1 batch 241 Train accuracy: 0.10360085964202881 Test accuracy: 0.09142452478408813
# Minibatch at Epoch 1 batch 251 Train accuracy: 0.09587401151657104 Test accuracy: 0.08833080530166626
# Minibatch at Epoch 1 batch 261 Train accuracy: 0.09830319881439209 Test accuracy: 0.14536041021347046
# Minibatch at Epoch 1 batch 271 Train accuracy: 0.10281252861022949 Test accuracy: 0.08998268842697144
# Minibatch at Epoch 1 batch 281 Train accuracy: 0.10264796018600464 Test accuracy: 0.09594810009002686
# Minibatch at Epoch 1 batch 291 Train accuracy: 0.09802061319351196 Test accuracy: 0.08341783285140991
# Minibatch at Epoch 1 batch 301 Train accuracy: 0.10506397485733032 Test accuracy: 0.08791792392730713
# Minibatch at Epoch 1 batch 311 Train accuracy: 0.10262471437454224 Test accuracy: 0.11393582820892334
# Minibatch at Epoch 1 batch 321 Train accuracy: 0.11470729112625122 Test accuracy: 0.09788954257965088
# Minibatch at Epoch 1 batch 331 Train accuracy: 0.11206811666488647 Test accuracy: 0.09946620464324951
# Minibatch at Epoch 1 batch 341 Train accuracy: 0.094970703125 Test accuracy: 0.09475934505462646
# Minibatch at Epoch 1 batch 351 Train accuracy: 0.0972142219543457 Test accuracy: 0.10156089067459106
# Minibatch at Epoch 1 batch 361 Train accuracy: 0.10332691669464111 Test accuracy: 0.09126752614974976
# Minibatch at Epoch 1 batch 371 Train accuracy: 0.0975421667098999 Test accuracy: 0.10069167613983154
# Minibatch at Epoch 1 batch 381 Train accuracy: 0.12908446788787842 Test accuracy: 0.08292436599731445
# Minibatch at Epoch 1 batch 391 Train accuracy: 0.11387860774993896 Test accuracy: 0.11624276638031006
# Minibatch at Epoch 1 batch 401 Train accuracy: 0.09268695116043091 Test accuracy: 0.09337359666824341
# Minibatch at Epoch 1 batch 411 Train accuracy: 0.10680931806564331 Test accuracy: 0.08190232515335083
# Minibatch at Epoch 1 batch 421 Train accuracy: 0.11047816276550293 Test accuracy: 0.1002875566482544
# Minibatch at Epoch 1 batch 431 Train accuracy: 0.1040651798248291 Test accuracy: 0.16894817352294922
# Minibatch at Epoch 1 batch 441 Train accuracy: 0.10143154859542847 Test accuracy: 0.09779644012451172
# Minibatch at Epoch 1 batch 451 Train accuracy: 0.09515750408172607 Test accuracy: 0.10058879852294922
# Minibatch at Epoch 1 batch 461 Train accuracy: 0.09824800491333008 Test accuracy: 0.09492528438568115
# -------------------------------------------------------------------------------------------------------
# After Epoch 1 Hybrid Test accuracy: 0.09943568706512451 Dice Test accuracy: 0.0018979907035827637 Focal Test accuracy: 0.3589518070220947 MSE Test accuracy: 0.7904475629329681
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 2 batch 1 Train accuracy: 0.12072664499282837 Test accuracy: 0.10767245292663574
# Minibatch at Epoch 2 batch 11 Train accuracy: 0.09250390529632568 Test accuracy: 0.10040104389190674
# Minibatch at Epoch 2 batch 21 Train accuracy: 0.0940169095993042 Test accuracy: 0.10886180400848389
# Minibatch at Epoch 2 batch 31 Train accuracy: 0.0923261046409607 Test accuracy: 0.12174540758132935
# Minibatch at Epoch 2 batch 41 Train accuracy: 0.09625226259231567 Test accuracy: 0.09870368242263794
# Minibatch at Epoch 2 batch 51 Train accuracy: 0.11207032203674316 Test accuracy: 0.08728557825088501
# Minibatch at Epoch 2 batch 61 Train accuracy: 0.10643208026885986 Test accuracy: 0.10690975189208984
# Minibatch at Epoch 2 batch 71 Train accuracy: 0.10104870796203613 Test accuracy: 0.14430385828018188
# Minibatch at Epoch 2 batch 81 Train accuracy: 0.09532856941223145 Test accuracy: 0.12338000535964966
# Minibatch at Epoch 2 batch 91 Train accuracy: 0.11053889989852905 Test accuracy: 0.09594309329986572
# Minibatch at Epoch 2 batch 101 Train accuracy: 0.12867552042007446 Test accuracy: 0.08504241704940796
# Minibatch at Epoch 2 batch 111 Train accuracy: 0.10335862636566162 Test accuracy: 0.09925419092178345
# Minibatch at Epoch 2 batch 121 Train accuracy: 0.09568071365356445 Test accuracy: 0.10479170083999634
# Minibatch at Epoch 2 batch 131 Train accuracy: 0.10690712928771973 Test accuracy: 0.10791438817977905
# Minibatch at Epoch 2 batch 141 Train accuracy: 0.127125084400177 Test accuracy: 0.1081969141960144
# Minibatch at Epoch 2 batch 151 Train accuracy: 0.11616581678390503 Test accuracy: 0.09294486045837402
# Minibatch at Epoch 2 batch 161 Train accuracy: 0.10916298627853394 Test accuracy: 0.10443753004074097
# Minibatch at Epoch 2 batch 171 Train accuracy: 0.11481523513793945 Test accuracy: 0.10657399892807007
# Minibatch at Epoch 2 batch 181 Train accuracy: 0.11028271913528442 Test accuracy: 0.098804771900177
# Minibatch at Epoch 2 batch 191 Train accuracy: 0.09447777271270752 Test accuracy: 0.1038404107093811
# Minibatch at Epoch 2 batch 201 Train accuracy: 0.10658317804336548 Test accuracy: 0.09681850671768188
# Minibatch at Epoch 2 batch 211 Train accuracy: 0.09105449914932251 Test accuracy: 0.07679015398025513
# Minibatch at Epoch 2 batch 221 Train accuracy: 0.13050121068954468 Test accuracy: 0.07703906297683716
# Minibatch at Epoch 2 batch 231 Train accuracy: 0.13159137964248657 Test accuracy: 0.09999120235443115
# Minibatch at Epoch 2 batch 241 Train accuracy: 0.10217946767807007 Test accuracy: 0.14432978630065918
# Minibatch at Epoch 2 batch 251 Train accuracy: 0.10459840297698975 Test accuracy: 0.11242854595184326
# Minibatch at Epoch 2 batch 261 Train accuracy: 0.1075059175491333 Test accuracy: 0.10167050361633301
# Minibatch at Epoch 2 batch 271 Train accuracy: 0.1445467472076416 Test accuracy: 0.09752792119979858
# Minibatch at Epoch 2 batch 281 Train accuracy: 0.09233486652374268 Test accuracy: 0.1016080379486084
# Minibatch at Epoch 2 batch 291 Train accuracy: 0.11372506618499756 Test accuracy: 0.16912305355072021
# Minibatch at Epoch 2 batch 301 Train accuracy: 0.09694480895996094 Test accuracy: 0.1060057282447815
# Minibatch at Epoch 2 batch 311 Train accuracy: 0.1291508674621582 Test accuracy: 0.11771070957183838
# Minibatch at Epoch 2 batch 321 Train accuracy: 0.11544978618621826 Test accuracy: 0.12414133548736572
# Minibatch at Epoch 2 batch 331 Train accuracy: 0.08878517150878906 Test accuracy: 0.07639205455780029
# Minibatch at Epoch 2 batch 341 Train accuracy: 0.10651916265487671 Test accuracy: 0.09543490409851074
# Minibatch at Epoch 2 batch 351 Train accuracy: 0.10223335027694702 Test accuracy: 0.0913851261138916
# Minibatch at Epoch 2 batch 361 Train accuracy: 0.10127002000808716 Test accuracy: 0.1042473316192627
# Minibatch at Epoch 2 batch 371 Train accuracy: 0.11154812574386597 Test accuracy: 0.10078668594360352
# Minibatch at Epoch 2 batch 381 Train accuracy: 0.1195303201675415 Test accuracy: 0.09744012355804443
# Minibatch at Epoch 2 batch 391 Train accuracy: 0.10985511541366577 Test accuracy: 0.11005169153213501
# Minibatch at Epoch 2 batch 401 Train accuracy: 0.11446833610534668 Test accuracy: 0.1064874529838562
# Minibatch at Epoch 2 batch 411 Train accuracy: 0.11047506332397461 Test accuracy: 0.11035579442977905
# Minibatch at Epoch 2 batch 421 Train accuracy: 0.10427224636077881 Test accuracy: 0.08422017097473145
# Minibatch at Epoch 2 batch 431 Train accuracy: 0.09757739305496216 Test accuracy: 0.10595506429672241
# Minibatch at Epoch 2 batch 441 Train accuracy: 0.09750998020172119 Test accuracy: 0.11014002561569214
# Minibatch at Epoch 2 batch 451 Train accuracy: 0.10267376899719238 Test accuracy: 0.09474480152130127
# Minibatch at Epoch 2 batch 461 Train accuracy: 0.10195881128311157 Test accuracy: 0.10915464162826538
# -------------------------------------------------------------------------------------------------------
# After Epoch 2 Hybrid Test accuracy: 0.09757006168365479 Dice Test accuracy: 0.00023055076599121094 Focal Test accuracy: 0.3563697338104248 MSE Test accuracy: 0.7879346311092377
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 3 batch 1 Train accuracy: 0.10824811458587646 Test accuracy: 0.11428368091583252
# Minibatch at Epoch 3 batch 11 Train accuracy: 0.10997200012207031 Test accuracy: 0.110279381275177
# Minibatch at Epoch 3 batch 21 Train accuracy: 0.1115465760231018 Test accuracy: 0.07804751396179199
# Minibatch at Epoch 3 batch 31 Train accuracy: 0.11942058801651001 Test accuracy: 0.10845279693603516
# Minibatch at Epoch 3 batch 41 Train accuracy: 0.1123693585395813 Test accuracy: 0.15008705854415894
# Minibatch at Epoch 3 batch 51 Train accuracy: 0.10347974300384521 Test accuracy: 0.10411304235458374
# Minibatch at Epoch 3 batch 61 Train accuracy: 0.12815791368484497 Test accuracy: 0.10680913925170898
# Minibatch at Epoch 3 batch 71 Train accuracy: 0.10388308763504028 Test accuracy: 0.14775168895721436
# Minibatch at Epoch 3 batch 81 Train accuracy: 0.11054152250289917 Test accuracy: 0.15003830194473267
# Minibatch at Epoch 3 batch 91 Train accuracy: 0.10501658916473389 Test accuracy: 0.08440220355987549
# Minibatch at Epoch 3 batch 101 Train accuracy: 0.11913925409317017 Test accuracy: 0.08396285772323608
# Minibatch at Epoch 3 batch 111 Train accuracy: 0.10637271404266357 Test accuracy: 0.10061275959014893
# Minibatch at Epoch 3 batch 121 Train accuracy: 0.10188698768615723 Test accuracy: 0.14569741487503052
# Minibatch at Epoch 3 batch 131 Train accuracy: 0.10917168855667114 Test accuracy: 0.0933459997177124
# Minibatch at Epoch 3 batch 141 Train accuracy: 0.11224955320358276 Test accuracy: 0.09759986400604248
# Minibatch at Epoch 3 batch 151 Train accuracy: 0.11035901308059692 Test accuracy: 0.0766977071762085
# Minibatch at Epoch 3 batch 161 Train accuracy: 0.1274595856666565 Test accuracy: 0.10665404796600342
# Minibatch at Epoch 3 batch 171 Train accuracy: 0.09901928901672363 Test accuracy: 0.10414230823516846
# Minibatch at Epoch 3 batch 181 Train accuracy: 0.11516058444976807 Test accuracy: 0.1156158447265625
# Minibatch at Epoch 3 batch 191 Train accuracy: 0.10791534185409546 Test accuracy: 0.12321990728378296
# Minibatch at Epoch 3 batch 201 Train accuracy: 0.10776352882385254 Test accuracy: 0.0890042781829834
# Minibatch at Epoch 3 batch 211 Train accuracy: 0.07517457008361816 Test accuracy: 0.09167718887329102
# Minibatch at Epoch 3 batch 221 Train accuracy: 0.11256605386734009 Test accuracy: 0.09448575973510742
# Minibatch at Epoch 3 batch 231 Train accuracy: 0.11440229415893555 Test accuracy: 0.09856444597244263
# Minibatch at Epoch 3 batch 241 Train accuracy: 0.1107286810874939 Test accuracy: 0.11278200149536133
# Minibatch at Epoch 3 batch 251 Train accuracy: 0.17820727825164795 Test accuracy: 0.10425406694412231
# Minibatch at Epoch 3 batch 261 Train accuracy: 0.09507131576538086 Test accuracy: 0.1483442783355713
# Minibatch at Epoch 3 batch 271 Train accuracy: 0.1293838620185852 Test accuracy: 0.10249584913253784
# Minibatch at Epoch 3 batch 281 Train accuracy: 0.11521381139755249 Test accuracy: 0.0918881893157959
# Minibatch at Epoch 3 batch 291 Train accuracy: 0.13109922409057617 Test accuracy: 0.10554200410842896
# Minibatch at Epoch 3 batch 301 Train accuracy: 0.11978882551193237 Test accuracy: 0.09712940454483032
# Minibatch at Epoch 3 batch 311 Train accuracy: 0.10319942235946655 Test accuracy: 0.10223448276519775
# Minibatch at Epoch 3 batch 321 Train accuracy: 0.1293690800666809 Test accuracy: 0.11673271656036377
# Minibatch at Epoch 3 batch 331 Train accuracy: 0.14873957633972168 Test accuracy: 0.17517215013504028
# Minibatch at Epoch 3 batch 341 Train accuracy: 0.11856871843338013 Test accuracy: 0.09044522047042847
# Minibatch at Epoch 3 batch 351 Train accuracy: 0.11268430948257446 Test accuracy: 0.15026551485061646
# Minibatch at Epoch 3 batch 361 Train accuracy: 0.11112892627716064 Test accuracy: 0.09445363283157349
# Minibatch at Epoch 3 batch 371 Train accuracy: 0.15109902620315552 Test accuracy: 0.11021542549133301
# Minibatch at Epoch 3 batch 381 Train accuracy: 0.09956425428390503 Test accuracy: 0.08997583389282227
# Minibatch at Epoch 3 batch 391 Train accuracy: 0.11524617671966553 Test accuracy: 0.08475834131240845
# Minibatch at Epoch 3 batch 401 Train accuracy: 0.17431789636611938 Test accuracy: 0.10819631814956665
# Minibatch at Epoch 3 batch 411 Train accuracy: 0.11587828397750854 Test accuracy: 0.07852953672409058
# Minibatch at Epoch 3 batch 421 Train accuracy: 0.10824960470199585 Test accuracy: 0.09885162115097046
# Minibatch at Epoch 3 batch 431 Train accuracy: 0.10039329528808594 Test accuracy: 0.11363804340362549
# Minibatch at Epoch 3 batch 441 Train accuracy: 0.0976760983467102 Test accuracy: 0.09248876571655273
# Minibatch at Epoch 3 batch 451 Train accuracy: 0.10508608818054199 Test accuracy: 0.10682833194732666
# Minibatch at Epoch 3 batch 461 Train accuracy: 0.1089586615562439 Test accuracy: 0.11380630731582642
# -------------------------------------------------------------------------------------------------------
# After Epoch 3 Hybrid Test accuracy: 0.09594869613647461 Dice Test accuracy: 0.0013595223426818848 Focal Test accuracy: 0.3377121686935425 MSE Test accuracy: 0.8057021200656891
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 4 batch 1 Train accuracy: 0.10775989294052124 Test accuracy: 0.17822140455245972
# Minibatch at Epoch 4 batch 11 Train accuracy: 0.11368000507354736 Test accuracy: 0.14342689514160156
# Minibatch at Epoch 4 batch 21 Train accuracy: 0.12808126211166382 Test accuracy: 0.11771714687347412
# Minibatch at Epoch 4 batch 31 Train accuracy: 0.15597623586654663 Test accuracy: 0.10034501552581787
# Minibatch at Epoch 4 batch 41 Train accuracy: 0.11924189329147339 Test accuracy: 0.1019476056098938
# Minibatch at Epoch 4 batch 51 Train accuracy: 0.10156118869781494 Test accuracy: 0.10412567853927612
# Minibatch at Epoch 4 batch 61 Train accuracy: 0.11478149890899658 Test accuracy: 0.11573559045791626
# Minibatch at Epoch 4 batch 71 Train accuracy: 0.09770745038986206 Test accuracy: 0.10630810260772705
# Minibatch at Epoch 4 batch 81 Train accuracy: 0.11989957094192505 Test accuracy: 0.10268354415893555
# Minibatch at Epoch 4 batch 91 Train accuracy: 0.11430346965789795 Test accuracy: 0.11555695533752441
# Minibatch at Epoch 4 batch 101 Train accuracy: 0.11630392074584961 Test accuracy: 0.10378944873809814
# Minibatch at Epoch 4 batch 111 Train accuracy: 0.14986449480056763 Test accuracy: 0.06549781560897827
# Minibatch at Epoch 4 batch 121 Train accuracy: 0.10662108659744263 Test accuracy: 0.05607867240905762
# Minibatch at Epoch 4 batch 131 Train accuracy: 0.09559375047683716 Test accuracy: 0.1124187707901001
# Minibatch at Epoch 4 batch 141 Train accuracy: 0.13369059562683105 Test accuracy: -0.518657922744751
# Minibatch at Epoch 4 batch 151 Train accuracy: 0.13307833671569824 Test accuracy: 0.10363554954528809
# Minibatch at Epoch 4 batch 161 Train accuracy: 0.12727534770965576 Test accuracy: 0.11432439088821411
# Minibatch at Epoch 4 batch 171 Train accuracy: 0.11931437253952026 Test accuracy: 0.11609512567520142
# Minibatch at Epoch 4 batch 181 Train accuracy: 0.12461239099502563 Test accuracy: 0.10704118013381958
# Minibatch at Epoch 4 batch 191 Train accuracy: 0.1276039481163025 Test accuracy: 0.11198842525482178
# Minibatch at Epoch 4 batch 201 Train accuracy: 0.12422710657119751 Test accuracy: 0.10776644945144653
# Minibatch at Epoch 4 batch 211 Train accuracy: 0.1390588879585266 Test accuracy: 0.15118283033370972
# Minibatch at Epoch 4 batch 221 Train accuracy: 0.11436158418655396 Test accuracy: 0.11443871259689331
# Minibatch at Epoch 4 batch 231 Train accuracy: 0.11960422992706299 Test accuracy: 0.08603322505950928
# Minibatch at Epoch 4 batch 241 Train accuracy: 0.1319293975830078 Test accuracy: 0.08333402872085571
# Minibatch at Epoch 4 batch 251 Train accuracy: 0.13543611764907837 Test accuracy: 0.08448266983032227
# Minibatch at Epoch 4 batch 261 Train accuracy: 0.11260902881622314 Test accuracy: 0.1133568286895752
# Minibatch at Epoch 4 batch 271 Train accuracy: 0.11039978265762329 Test accuracy: 0.11985492706298828
# Minibatch at Epoch 4 batch 281 Train accuracy: 0.12934166193008423 Test accuracy: 0.11317479610443115
# Minibatch at Epoch 4 batch 291 Train accuracy: 0.11409378051757812 Test accuracy: 0.11453825235366821
# Minibatch at Epoch 4 batch 301 Train accuracy: 0.1386566162109375 Test accuracy: 0.09850460290908813
# Minibatch at Epoch 4 batch 311 Train accuracy: 0.13755667209625244 Test accuracy: 0.10445421934127808
# Minibatch at Epoch 4 batch 321 Train accuracy: 0.12790757417678833 Test accuracy: 0.10907876491546631
# Minibatch at Epoch 4 batch 331 Train accuracy: 0.12712520360946655 Test accuracy: 0.1140204668045044
# Minibatch at Epoch 4 batch 341 Train accuracy: 0.12046277523040771 Test accuracy: 0.11498421430587769
# Minibatch at Epoch 4 batch 351 Train accuracy: 0.11276304721832275 Test accuracy: 0.10434144735336304
# Minibatch at Epoch 4 batch 361 Train accuracy: 0.1420610547065735 Test accuracy: 0.12195354700088501
# Minibatch at Epoch 4 batch 371 Train accuracy: 0.11485862731933594 Test accuracy: 0.1189810037612915
# Minibatch at Epoch 4 batch 381 Train accuracy: 0.15793699026107788 Test accuracy: 0.12211710214614868
# Minibatch at Epoch 4 batch 391 Train accuracy: 0.12439048290252686 Test accuracy: 0.11624634265899658
# Minibatch at Epoch 4 batch 401 Train accuracy: 0.1336497664451599 Test accuracy: 0.11647003889083862
# Minibatch at Epoch 4 batch 411 Train accuracy: 0.12273144721984863 Test accuracy: 0.18368089199066162
# Minibatch at Epoch 4 batch 421 Train accuracy: 0.12854862213134766 Test accuracy: 0.09166669845581055
# Minibatch at Epoch 4 batch 431 Train accuracy: 0.12251627445220947 Test accuracy: 0.13170266151428223
# Minibatch at Epoch 4 batch 441 Train accuracy: 0.13716989755630493 Test accuracy: 0.0934978723526001
# Minibatch at Epoch 4 batch 451 Train accuracy: 0.15893709659576416 Test accuracy: 0.11248743534088135
# Minibatch at Epoch 4 batch 461 Train accuracy: 0.11073720455169678 Test accuracy: 0.10277992486953735
# -------------------------------------------------------------------------------------------------------
# After Epoch 4 Hybrid Test accuracy: 0.18077826499938965 Dice Test accuracy: 0.0 Focal Test accuracy: 0.8148097693920135 MSE Test accuracy: 0.8493578881025314
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 5 batch 1 Train accuracy: 0.12080013751983643 Test accuracy: 0.11937040090560913
# Minibatch at Epoch 5 batch 11 Train accuracy: 0.12771689891815186 Test accuracy: 0.09272271394729614
# Minibatch at Epoch 5 batch 21 Train accuracy: 0.14194512367248535 Test accuracy: 0.0888981819152832
# Minibatch at Epoch 5 batch 31 Train accuracy: 0.1325264573097229 Test accuracy: 0.11820846796035767
# Minibatch at Epoch 5 batch 41 Train accuracy: 0.13915938138961792 Test accuracy: 0.11230731010437012
# Minibatch at Epoch 5 batch 51 Train accuracy: 0.15889906883239746 Test accuracy: 0.14823341369628906
# Minibatch at Epoch 5 batch 61 Train accuracy: 0.15677988529205322 Test accuracy: 0.12442910671234131
# Minibatch at Epoch 5 batch 71 Train accuracy: 0.11878198385238647 Test accuracy: 0.12870526313781738
# Minibatch at Epoch 5 batch 81 Train accuracy: 0.1362130045890808 Test accuracy: 0.14932674169540405
# Minibatch at Epoch 5 batch 91 Train accuracy: 0.1734585165977478 Test accuracy: 0.10843384265899658
# Minibatch at Epoch 5 batch 101 Train accuracy: 0.15889722108840942 Test accuracy: 0.12960606813430786
# Minibatch at Epoch 5 batch 111 Train accuracy: 0.16633152961730957 Test accuracy: 0.13481849431991577
# Minibatch at Epoch 5 batch 121 Train accuracy: 0.11778682470321655 Test accuracy: 0.09522002935409546
# Minibatch at Epoch 5 batch 131 Train accuracy: 0.13991641998291016 Test accuracy: 0.16757482290267944
# Minibatch at Epoch 5 batch 141 Train accuracy: 0.1384657621383667 Test accuracy: 0.12778949737548828
# Minibatch at Epoch 5 batch 151 Train accuracy: 0.1297282576560974 Test accuracy: 0.16625350713729858
# Minibatch at Epoch 5 batch 161 Train accuracy: 0.1370580792427063 Test accuracy: 0.1255662441253662
# Minibatch at Epoch 5 batch 171 Train accuracy: 0.11586147546768188 Test accuracy: 0.1167672872543335
# Minibatch at Epoch 5 batch 181 Train accuracy: 0.11110913753509521 Test accuracy: 0.11785256862640381
# Minibatch at Epoch 5 batch 191 Train accuracy: 0.11701995134353638 Test accuracy: 0.11949008703231812
# Minibatch at Epoch 5 batch 201 Train accuracy: 0.12191712856292725 Test accuracy: 0.1192426085472107
# Minibatch at Epoch 5 batch 211 Train accuracy: 0.13815802335739136 Test accuracy: 0.11695343255996704
# Minibatch at Epoch 5 batch 221 Train accuracy: 0.1418091058731079 Test accuracy: 0.13334673643112183
# Minibatch at Epoch 5 batch 231 Train accuracy: 0.14989566802978516 Test accuracy: 0.14495909214019775
# Minibatch at Epoch 5 batch 241 Train accuracy: 0.12921667098999023 Test accuracy: 0.12481611967086792
# Minibatch at Epoch 5 batch 251 Train accuracy: 0.14093732833862305 Test accuracy: 0.12775349617004395
# Minibatch at Epoch 5 batch 261 Train accuracy: 0.15821415185928345 Test accuracy: 0.162075936794281
# Minibatch at Epoch 5 batch 271 Train accuracy: 0.1376509666442871 Test accuracy: 0.11904478073120117
# Minibatch at Epoch 5 batch 281 Train accuracy: 0.1384708285331726 Test accuracy: 0.13244205713272095
# Minibatch at Epoch 5 batch 291 Train accuracy: 0.1315966248512268 Test accuracy: 0.11835485696792603
# Minibatch at Epoch 5 batch 301 Train accuracy: 0.14684855937957764 Test accuracy: 0.13792407512664795
# Minibatch at Epoch 5 batch 311 Train accuracy: 0.14725613594055176 Test accuracy: 0.12669634819030762
# Minibatch at Epoch 5 batch 321 Train accuracy: 0.12967848777770996 Test accuracy: 0.11696290969848633
# Minibatch at Epoch 5 batch 331 Train accuracy: 0.14535969495773315 Test accuracy: 0.1280989646911621
# Minibatch at Epoch 5 batch 341 Train accuracy: 0.13617682456970215 Test accuracy: 0.15663492679595947
# Minibatch at Epoch 5 batch 351 Train accuracy: 0.14037585258483887 Test accuracy: 0.12628662586212158
# Minibatch at Epoch 5 batch 361 Train accuracy: 0.13971394300460815 Test accuracy: 0.13211768865585327
# Minibatch at Epoch 5 batch 371 Train accuracy: 0.1405734419822693 Test accuracy: 0.1503729224205017
# Minibatch at Epoch 5 batch 381 Train accuracy: 0.1310347318649292 Test accuracy: 0.12136447429656982
# Minibatch at Epoch 5 batch 391 Train accuracy: 0.12387114763259888 Test accuracy: 0.12266498804092407
# Minibatch at Epoch 5 batch 401 Train accuracy: 0.17307454347610474 Test accuracy: 0.16508245468139648
# Minibatch at Epoch 5 batch 411 Train accuracy: 0.13147443532943726 Test accuracy: 0.1330643892288208
# Minibatch at Epoch 5 batch 421 Train accuracy: 0.11953693628311157 Test accuracy: 0.1428472399711609
# Minibatch at Epoch 5 batch 431 Train accuracy: 0.16947931051254272 Test accuracy: 0.1327347755432129
# Minibatch at Epoch 5 batch 441 Train accuracy: 0.17903178930282593 Test accuracy: 0.15064573287963867
# Minibatch at Epoch 5 batch 451 Train accuracy: 0.13819682598114014 Test accuracy: 0.1400827169418335
# Minibatch at Epoch 5 batch 461 Train accuracy: 0.15479928255081177 Test accuracy: 0.0963282585144043
# -------------------------------------------------------------------------------------------------------
# After Epoch 5 Hybrid Test accuracy: 0.132895827293396 Dice Test accuracy: 0.0005781650543212891 Focal Test accuracy: 0.516499400138855 MSE Test accuracy: 0.9441115632653236
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 6 batch 1 Train accuracy: 0.12809520959854126 Test accuracy: 0.17950439453125
# Minibatch at Epoch 6 batch 11 Train accuracy: 0.1367095708847046 Test accuracy: 0.1490270495414734
# Minibatch at Epoch 6 batch 21 Train accuracy: 0.1313139796257019 Test accuracy: 0.14252722263336182
# Minibatch at Epoch 6 batch 31 Train accuracy: 0.1710742712020874 Test accuracy: 0.13500189781188965
# Minibatch at Epoch 6 batch 41 Train accuracy: 0.12685853242874146 Test accuracy: 0.1144898533821106
# Minibatch at Epoch 6 batch 51 Train accuracy: 0.133620023727417 Test accuracy: 0.13476473093032837
# Minibatch at Epoch 6 batch 61 Train accuracy: 0.1338334083557129 Test accuracy: 0.13520240783691406
# Minibatch at Epoch 6 batch 71 Train accuracy: 0.12798303365707397 Test accuracy: 0.2038288116455078
# Minibatch at Epoch 6 batch 81 Train accuracy: 0.16253167390823364 Test accuracy: 0.1415923833847046
# Minibatch at Epoch 6 batch 91 Train accuracy: 0.19402015209197998 Test accuracy: 0.16204315423965454
# Minibatch at Epoch 6 batch 101 Train accuracy: 0.1759103536605835 Test accuracy: 0.12591016292572021
# Minibatch at Epoch 6 batch 111 Train accuracy: 0.16952699422836304 Test accuracy: 0.12490427494049072
# Minibatch at Epoch 6 batch 121 Train accuracy: 0.15355312824249268 Test accuracy: 0.16699856519699097
# Minibatch at Epoch 6 batch 131 Train accuracy: 0.1373569369316101 Test accuracy: 0.1545444130897522
# Minibatch at Epoch 6 batch 141 Train accuracy: 0.15567147731781006 Test accuracy: 0.13252604007720947
# Minibatch at Epoch 6 batch 151 Train accuracy: 0.14549851417541504 Test accuracy: 0.10241997241973877
# Minibatch at Epoch 6 batch 161 Train accuracy: 0.2111799120903015 Test accuracy: 0.12904661893844604
# Minibatch at Epoch 6 batch 171 Train accuracy: 0.146600604057312 Test accuracy: 0.13435953855514526
# Minibatch at Epoch 6 batch 181 Train accuracy: 0.1405777931213379 Test accuracy: 0.17522794008255005
# Minibatch at Epoch 6 batch 191 Train accuracy: 0.1736356019973755 Test accuracy: 0.1181371808052063
# Minibatch at Epoch 6 batch 201 Train accuracy: 0.1331966519355774 Test accuracy: 0.20211482048034668
# Minibatch at Epoch 6 batch 211 Train accuracy: 0.1971604824066162 Test accuracy: 0.17037546634674072
# Minibatch at Epoch 6 batch 221 Train accuracy: 0.14301025867462158 Test accuracy: 0.19988203048706055
# Minibatch at Epoch 6 batch 231 Train accuracy: 0.13434314727783203 Test accuracy: 0.1415049433708191
# Minibatch at Epoch 6 batch 241 Train accuracy: 0.15206867456436157 Test accuracy: 0.1370031237602234
# Minibatch at Epoch 6 batch 251 Train accuracy: 0.1606208086013794 Test accuracy: 0.1667819619178772
# Minibatch at Epoch 6 batch 261 Train accuracy: 0.14123350381851196 Test accuracy: 0.1282939314842224
# Minibatch at Epoch 6 batch 271 Train accuracy: 0.15917092561721802 Test accuracy: 0.13604342937469482
# Minibatch at Epoch 6 batch 281 Train accuracy: 0.13254815340042114 Test accuracy: 0.14025354385375977
# Minibatch at Epoch 6 batch 291 Train accuracy: 0.17896896600723267 Test accuracy: 0.1201663613319397
# Minibatch at Epoch 6 batch 301 Train accuracy: 0.16526222229003906 Test accuracy: 0.1378324031829834
# Minibatch at Epoch 6 batch 311 Train accuracy: 0.1869717836380005 Test accuracy: 0.1459054946899414
# Minibatch at Epoch 6 batch 321 Train accuracy: 0.12031000852584839 Test accuracy: 0.16422438621520996
# Minibatch at Epoch 6 batch 331 Train accuracy: 0.15256011486053467 Test accuracy: 0.13706648349761963
# Minibatch at Epoch 6 batch 341 Train accuracy: 0.1645721197128296 Test accuracy: 0.17079389095306396
# Minibatch at Epoch 6 batch 351 Train accuracy: 0.15507835149765015 Test accuracy: 0.15713083744049072
# Minibatch at Epoch 6 batch 361 Train accuracy: 0.15702253580093384 Test accuracy: 0.14376097917556763
# Minibatch at Epoch 6 batch 371 Train accuracy: 0.13245552778244019 Test accuracy: 0.1344280242919922
# Minibatch at Epoch 6 batch 381 Train accuracy: 0.13534200191497803 Test accuracy: 0.13849914073944092
# Minibatch at Epoch 6 batch 391 Train accuracy: 0.15251851081848145 Test accuracy: 0.125482976436615
# Minibatch at Epoch 6 batch 401 Train accuracy: 0.17801088094711304 Test accuracy: -0.016799449920654297
# Minibatch at Epoch 6 batch 411 Train accuracy: 0.15493017435073853 Test accuracy: 0.18216079473495483
# Minibatch at Epoch 6 batch 421 Train accuracy: 0.13494181632995605 Test accuracy: 0.13775527477264404
# Minibatch at Epoch 6 batch 431 Train accuracy: 0.13737738132476807 Test accuracy: 0.14095914363861084
# Minibatch at Epoch 6 batch 441 Train accuracy: 0.13014435768127441 Test accuracy: 0.13713479042053223
# Minibatch at Epoch 6 batch 451 Train accuracy: 0.13848161697387695 Test accuracy: 0.13251155614852905
# Minibatch at Epoch 6 batch 461 Train accuracy: 0.16435492038726807 Test accuracy: 0.12419110536575317
# -------------------------------------------------------------------------------------------------------
# After Epoch 6 Hybrid Test accuracy: 0.11642259359359741 Dice Test accuracy: 0.005610167980194092 Focal Test accuracy: 0.4031587243080139 MSE Test accuracy: 0.9338793382048607
# -------------------------------------------------------------------------------------------------------
# Minibatch at Epoch 7 batch 1 Train accuracy: 0.14143705368041992 Test accuracy: 0.13597530126571655
# Minibatch at Epoch 7 batch 11 Train accuracy: 0.1508859395980835 Test accuracy: 0.17219114303588867
# Minibatch at Epoch 7 batch 21 Train accuracy: 0.146484375 Test accuracy: 0.09080171585083008
# Minibatch at Epoch 7 batch 31 Train accuracy: 0.17937445640563965 Test accuracy: 0.12331682443618774
# Minibatch at Epoch 7 batch 41 Train accuracy: 0.15566211938858032 Test accuracy: 0.15402144193649292
# Minibatch at Epoch 7 batch 51 Train accuracy: 0.15815240144729614 Test accuracy: 0.18622255325317383
# Minibatch at Epoch 7 batch 61 Train accuracy: 0.190116286277771 Test accuracy: 0.12514573335647583
# Minibatch at Epoch 7 batch 71 Train accuracy: 0.1192629337310791 Test accuracy: 0.1374778151512146
# Minibatch at Epoch 7 batch 81 Train accuracy: 0.12448728084564209 Test accuracy: 0.17831212282180786
# Minibatch at Epoch 7 batch 91 Train accuracy: 0.16485369205474854 Test accuracy: 0.16721099615097046
# Minibatch at Epoch 7 batch 101 Train accuracy: 0.2000226378440857 Test accuracy: 0.14059442281723022
# Minibatch at Epoch 7 batch 111 Train accuracy: 0.05265289545059204 Test accuracy: 0.1514638066291809
# Minibatch at Epoch 7 batch 121 Train accuracy: 0.14349228143692017 Test accuracy: 0.12791889905929565
# Minibatch at Epoch 7 batch 131 Train accuracy: 0.1397915482521057 Test accuracy: 0.13026708364486694
# Minibatch at Epoch 7 batch 141 Train accuracy: 0.15909534692764282 Test accuracy: 0.1319713592529297
# Minibatch at Epoch 7 batch 151 Train accuracy: 0.14833539724349976 Test accuracy: 0.11796575784683228
# Minibatch at Epoch 7 batch 161 Train accuracy: 0.1831883192062378 Test accuracy: 0.15641528367996216
# Minibatch at Epoch 7 batch 171 Train accuracy: 0.13655978441238403 Test accuracy: 0.13525664806365967
# Minibatch at Epoch 7 batch 181 Train accuracy: 0.14114075899124146 Test accuracy: 0.12986475229263306
# Minibatch at Epoch 7 batch 191 Train accuracy: 0.14195877313613892 Test accuracy: 0.16824448108673096
# Minibatch at Epoch 7 batch 201 Train accuracy: 0.1351301670074463 Test accuracy: 0.10232317447662354
# Minibatch at Epoch 7 batch 211 Train accuracy: 0.15568727254867554 Test accuracy: 0.11957907676696777
# Minibatch at Epoch 7 batch 221 Train accuracy: 0.13571584224700928 Test accuracy: 0.12088000774383545
# Minibatch at Epoch 7 batch 231 Train accuracy: 0.15043634176254272 Test accuracy: 0.11899471282958984
# Minibatch at Epoch 7 batch 241 Train accuracy: 0.12911999225616455 Test accuracy: 0.16397392749786377
# Minibatch at Epoch 7 batch 251 Train accuracy: 0.17954570055007935 Test accuracy: 0.1608201265335083
# Minibatch at Epoch 7 batch 261 Train accuracy: 0.115481436252594 Test accuracy: 0.1347048282623291
# Minibatch at Epoch 7 batch 271 Train accuracy: 0.1779543161392212 Test accuracy: -0.9943952560424805
# Minibatch at Epoch 7 batch 281 Train accuracy: 0.15037864446640015 Test accuracy: 0.14195466041564941
# Minibatch at Epoch 7 batch 291 Train accuracy: 0.13089263439178467 Test accuracy: 0.1473754644393921
